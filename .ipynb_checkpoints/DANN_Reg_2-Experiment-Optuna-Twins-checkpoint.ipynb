# %%
import numpy as np
import pandas as pd
from scipy.special import expit
import random
import os
import gc
import math
import optuna
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.manifold import TSNE
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch import optim
from geomloss import SamplesLoss
from torch.autograd import Function
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.nn.functional import normalize
#from torchmetrics.classification import BinaryAccuracyS
from torchmetrics.classification import BinaryF1Score,BinaryAccuracy
from sklearn.preprocessing import StandardScaler
torch.manual_seed(42)

# %%
class Data(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X.astype(np.float32))
        self.y = torch.from_numpy(y.astype(np.float32))
        self.len = self.X.shape[0]
       
    def __getitem__(self, index):
        return self.X[index], self.y[index]
   
    def __len__(self):
        return self.len

# %%
def get_data(train_rate = 0.8):

    ori_data = np.loadtxt("Datasets/Twins/Twin_Data.csv", delimiter=",",skiprows=1)

    # Define features
    x = ori_data[:,:30]
    no, dim = x.shape
    potential_y = ori_data[:, 30:]
    # Die within 1 year = 1, otherwise = 0
    potential_y = np.array(potential_y < 9999,dtype=float) 
    ## Assign treatment
    coef = np.random.uniform(-0.01, 0.01, size = [dim,1])
    prob_temp = expit(np.matmul(x, coef) + np.random.normal(0,0.01, size = [no,1]))

    prob_t = prob_temp/(2*np.mean(prob_temp))
    prob_t[prob_t>1] = 1

    t = np.random.binomial(1,prob_t,[no,1])
    t = t.reshape([no,])
    y = np.zeros([no,1])
    y = np.transpose(t) * potential_y[:,1] + np.transpose(1-t) * potential_y[:,0]    
    y = np.reshape(np.transpose(y), [no, ])
    idx = np.random.permutation(no)
    train_idx = idx[:int(train_rate * no)]
    test_idx = idx[int(train_rate * no):]

    train_x = x[train_idx,:]
    # Normalization here
    #data_mean = np.mean(train_x, axis=0, keepdims=True)
    #data_std = np.std(train_x, axis=0, keepdims=True)

    #train_x = (train_x - data_mean) / data_std
    
    train_t = t[train_idx]
    train_y = pd.DataFrame(y[train_idx])
    train_potential_y = pd.DataFrame(potential_y[train_idx,:])

    test_x = x[test_idx,:]
    # Normalization here
    #test_x = (test_x - data_mean) / data_std
    
    test_x = pd.DataFrame(test_x)
    test_potential_y = pd.DataFrame(potential_y[test_idx,:])
    
    x_data=pd.DataFrame(train_x)
    t_data=pd.DataFrame(train_t)
    df_x_and_t=pd.concat([t_data,x_data],1)
    

    col=["treatment"]
    for i in range(1,31):
        col.append("x"+str(i)) 

    df_x_and_t.columns = col
    
    
    #return train_x, train_t, train_y, train_potential_y, test_x, test_potential_y
    return df_x_and_t,train_y,train_potential_y,test_x,test_potential_y

# %%
#train_x,train_y,train_potential_y,test_x,test_potential_y=get_data()

# %%
def get_dataloader(x_data,y_data,batch_size):

    x_train_sr=x_data[x_data['treatment']==0]
    y_train_sr=y_data[x_data['treatment']==0]
    x_train_tr=x_data[x_data['treatment']==1]
    y_train_tr=y_data[x_data['treatment']==1]


    train_data_sr = Data(np.array(x_train_sr), np.array(y_train_sr))
    train_dataloader_sr = DataLoader(dataset=train_data_sr, batch_size=batch_size)

    train_data_tr = Data(np.array(x_train_tr), np.array(y_train_tr))
    train_dataloader_tr = DataLoader(dataset=train_data_tr, batch_size=batch_size)


    return train_dataloader_sr, train_dataloader_tr

# %%
def regression_loss(concat_true, concat_pred):
    #computes a standard MSE loss for TARNet
    y_true = concat_true[:, 0] #get individual vectors
    t_true = concat_true[:, 1]

    y0_pred = concat_pred[:, 0]
    y1_pred = concat_pred[:, 1]

    #Each head outputs a prediction for both potential outcomes
    #We use t_true as a switch to only calculate the factual loss
    loss0 = torch.sum((1. - t_true) * torch.square(y_true - y0_pred))
    loss1 = torch.sum(t_true * torch.square(y_true - y1_pred))
    #note Shi uses tf.reduce_sum for her losses instead of tf.reduce_mean.
    #They should be equivalent but it's possible that having larger gradients accelerates convergence.
    #You can always try changing it!
    return loss0 + loss1

# %%
def loss_cal(X_data,y_data,net,alpha):
    b_accu = BinaryAccuracy()
    b_f1=BinaryF1Score()
    
    x_train_sr=X_data[X_data['treatment']==0]
    y_train_sr=y_data[X_data['treatment']==0]
    x_train_tr=X_data[X_data['treatment']==1]
    y_train_tr=y_data[X_data['treatment']==1]
    xs_t=x_train_sr.iloc[:,0].to_numpy()
    xt_t=x_train_tr.iloc[:,0].to_numpy()
    
    
    xs=x_train_sr.iloc[:,1:31].to_numpy()
    xt=x_train_tr.iloc[:,1:31].to_numpy()
    xs_t=torch.from_numpy(xs_t.astype(np.float32))
    xt_t=torch.from_numpy(xt_t.astype(np.float32))
    y_train_sr=y_train_sr.to_numpy()
    y_train_tr=y_train_tr.to_numpy()
    xs=torch.from_numpy(xs.astype(np.float32))
    xt=torch.from_numpy(xt.astype(np.float32))
    
    y_train_sr=torch.from_numpy(y_train_sr.astype(np.float32))
    y_train_tr=torch.from_numpy(y_train_tr.astype(np.float32))
    
    
    input_data=torch.cat((xs,xt),0)
    #true_y=torch.unsqueeze(torch.cat((y_train_sr,y_train_tr),0), dim=1)
    true_y=torch.cat((y_train_sr,y_train_tr),0)
    true_t=torch.unsqueeze(torch.cat((xs_t,xt_t),0), dim=1)
    
    
    concat_true=torch.cat((true_y,true_t),1)
    concat_pred,d_out,phi=net(input_data,alpha)
    loss=regression_loss(concat_true, concat_pred)
    
    
    
    t_actual=torch.cat((xs_t.type(torch.LongTensor),xt_t.type(torch.LongTensor)),0)
    
    domain_loss=criterion(d_out, t_actual)
    
    predicted = torch.argmax(d_out, dim=1)
    
    
    
    
    return domain_loss.item(),loss.item(),b_accu(predicted, t_actual.squeeze()),b_f1(predicted, t_actual.squeeze())

# %%
def objective(trial,i,x_data,y_data):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 512),
          'RL21': trial.suggest_int('RL21', 16, 512),
          'RL32': trial.suggest_int('RL32', 16, 512),
          'RG012':trial.suggest_int('RG012', 16, 512),
        'RG022':trial.suggest_int('RG022', 16, 512),
        'RG112':trial.suggest_int('RG112', 16, 512),
        'RG122':trial.suggest_int('RG122', 16, 512),
        'CL12':trial.suggest_int('CL12', 16, 512),
        'CL22':trial.suggest_int('CL22', 16, 512)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i,x_data,y_data)

    return pehe

# %%
# PEHE evaluation
def cal_pehe(data,y,model, alpha=0.5):
    #data,y=get_data('test',i)

    data=data.to_numpy()
    data=torch.from_numpy(data.astype(np.float32))
    
    y=y.to_numpy()
    y=torch.from_numpy(y.astype(np.float32))



    concat_pred,d_out,phi=model(data[:,0:30])
    #dont forget to rescale the outcome before estimation!
    #y0_pred = data['y_scaler'].inverse_transform(concat_pred[:, 0].reshape(-1, 1))
    #y1_pred = data['y_scaler'].inverse_transform(concat_pred[:, 1].reshape(-1, 1))
    #y0=scaler.inverse_transform(concat_pred[:,0].reshape(-1, 1))
    #y1=scaler.inverse_transform(concat_pred[:,1].reshape(-1, 1))
    cate_pred=concat_pred[:,1]-concat_pred[:,0]
    #cate_pred=y1-y0
    
    #cate_true=data[:,4]-data[:,3] #Hill's noiseless true values
    cate_true=y[:,1] - y[:,0]


    cate_err=torch.mean( torch.square( ( (cate_true) - (cate_pred) ) ) )

    return torch.sqrt(cate_err).item()

# %%
class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(30, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,out_d2,phi

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
epochs=300
#batch_size=32
criterion = nn.CrossEntropyLoss()
#x_data,y_data=get_data(0.9)

#criterion =nn.BCELoss()

# %%
train_loss=[]
val_loss=[]
train_accu=[]
val_accu=[]
val_f1=[]
train_f1=[]
train_tloss=[]
val_tloss=[]

d_loss=[]
pehe_error=[]
#num_files=2
def train_evaluate(param, model, trial,file_num,x_data,y_data):
    #for nf in range(1,num_files):
    X_train, X_val,y_train, y_val = train_test_split(x_data,y_data ,
                                       random_state=42, 
                                       test_size=0.27)
    
    
    
    #net=TarNet(25,.01)
    #opt_net = torch.optim.Adam(net.parameters(), lr=1e-4)
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
    
    optimizer = getattr(optim, param['optimizer'])(model.parameters(), lr= param['learning_rate'])
    
    if use_cuda:

        #model = model.cuda()
        model = model
        #criterion = criterion
  

    for ep in range(1,epochs+1 ):
        
        lamda_max=5
        e0=20
        train_dataloader_sr, train_dataloader_tr=get_dataloader(X_train,y_train,param['batch_size'])
        
        
        lambda_val=(lamda_max)*((ep-e0)/(epochs-e0))
        alpha=max(0,lambda_val)
        dis_loss=0
        total_loss=0
 
        for batch_idx, (train_source_data, train_target_data) in enumerate(zip(train_dataloader_sr, train_dataloader_tr)):
            
            xs,ys=train_source_data
            xt,yt=train_target_data
            
            xs_train=xs[:,1:31]
            xt_train=xt[:,1:31]
            #alpha=5
            
            train_x=torch.cat((xs_train,xt_train),0)
            #train_y=torch.unsqueeze(torch.cat((ys,yt),0), dim=1)
            train_y=torch.cat((ys,yt),0)
            true_t=torch.unsqueeze(torch.cat((xs[:,0],xt[:,0]),0), dim=1)
            concat_true=torch.cat((train_y,true_t),1)
            concat_pred,d_out,phi=model(train_x,alpha)
            
            
            #s_zeros_t=torch.zeros(xs_train.shape[0],1)
            #t_ones_t=torch.ones(xt_train.shape[0],1)

            #labels=torch.cat((s_zeros_t,t_ones_t),0)
           
            
            labels_discr=torch.cat((xs[:,0].type(torch.LongTensor),xt[:,0].type(torch.LongTensor)),0)
            #outputs_discr = domain_descr(phi,alpha)
            
            model.zero_grad()
            #opt_dis.zero_grad()
            

            #source_mse=criterion_reg(y0,ys)
            #target_mse=criterion_reg(y1,yt)
            domain_loss=criterion(d_out, labels_discr)
            reg_loss=regression_loss(concat_true,concat_pred)
            #combined loss
            combined_loss=domain_loss+reg_loss
            #print('Training loss: ',combined_loss.item())
            # backward propagation
            combined_loss.backward()
            dis_loss= dis_loss+domain_loss.item()
            total_loss=total_loss+combined_loss.item()
            # optimize
            optimizer.step()
            #opt_dis.step()
        #train_loss.append(loss_cal(X_train,y_train,model,alpha))
        #val_loss.append(loss_cal(X_val,y_val,model,alpha))
        d_loss.append(dis_loss)
        d_loss_tr,tr_los,tr_ac,tr_f1=loss_cal(X_train,y_train,model,alpha)
        d_loss_val,vl_los,vl_ac,vl_f1=loss_cal(X_val,y_val,model,alpha)
        train_tloss.append(d_loss_tr)
        train_loss.append(tr_los)
        train_accu.append(tr_ac)
        train_f1.append(tr_f1)
        
        val_loss.append(vl_los)
        val_accu.append(vl_ac)
        val_f1.append(vl_f1)
        val_tloss.append(d_loss_val)
        
        
    #return cal_pehe(X_val,y_val,model),model
    #return total_loss,model
    #return d_loss_val+vl_los,model
    return vl_los,model
    #return cal_pehe_nn(X_val,y_val,model,alpha),model

# %%
def clear_all():
    train_loss.clear()
    train_accu.clear()
    train_f1.clear()
    val_loss.clear()
    val_accu.clear()
    val_f1.clear()
    d_loss.clear()
    train_tloss.clear()
    val_tloss.clear()

# %%
pehe_total=[]
trails=50
#i=1
for i in range(1,11):
    x_data,y_data,train_p_y,test_x,test_p_y=get_data(0.9)
    func = lambda trial: objective(trial, i,x_data,y_data)
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(func, n_trials=trails)
    best_trial = study.best_trial
    best_model=TarNet(study.best_trial.params)
    clear_all()
    best_val,model=train_evaluate(study.best_trial.params, best_model, study.best_trial,i,x_data,y_data)
    #data,y=get_data('train',i)
    pehe=cal_pehe(x_data,train_p_y,model)
    print('# of files completed so far:',i)
    pehe_total.append(pehe)
    del best_model
    del model
    del study
    del x_data
    del y_data
    del train_p_y
    del test_x
    del test_p_y
    gc.collect()
# Out:
# /tmp/ipykernel_499214/2219756517.py:37: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_x_and_t=pd.concat([t_data,x_data],1)
# [I 2023-03-17 10:24:48,708] A new study created in memory with name: no-name-6b83cb58-8a24-4c63-a2cd-c8da67fb3557
# /tmp/ipykernel_499214/830509479.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-17 10:25:38,443] Trial 0 finished with value: 240.80413818359375 and parameters: {'learning_rate': 5.6115164153345e-05, 'optimizer': 'Adam', 'batch_size': 157, 'RL11': 93, 'RL21': 93, 'RL32': 44, 'RG012': 446, 'RG022': 314, 'RG112': 367, 'RG122': 26, 'CL12': 498, 'CL22': 429}. Best is trial 0 with value: 240.80413818359375.
# [I 2023-03-17 10:26:38,705] Trial 1 finished with value: 251.65542602539062 and parameters: {'learning_rate': 2.6587543983272695e-05, 'optimizer': 'SGD', 'batch_size': 83, 'RL11': 276, 'RL21': 230, 'RL32': 160, 'RG012': 320, 'RG022': 85, 'RG112': 161, 'RG122': 198, 'CL12': 242, 'CL22': 406}. Best is trial 0 with value: 240.80413818359375.
. Best is trial 20 with value: 237.32080078125.
# [I 2023-03-17 11:38:40,615] Trial 47 finished with value: 237.9591064453125 and parameters: {'learning_rate': 0.0002692865153529999, 'optimizer': 'SGD', 'batch_size': 100, 'RL11': 365, 'RL21': 420, 'RL32': 88, 'RG012': 391, 'RG022': 457, 'RG112': 170, 'RG122': 209, 'CL12': 453, 'CL22': 404}. Best is trial 20 with value: 237.32080078125.
# [I 2023-03-17 11:40:26,308] Trial 48 finished with value: 237.0233154296875 and parameters: {'learning_rate': 0.0002779048635121117, 'optimizer': 'SGD', 'batch_size': 88, 'RL11': 323, 'RL21': 424, 'RL32': 44, 'RG012': 354, 'RG022': 429, 'RG112': 46, 'RG122': 127, 'CL12': 445, 'CL22': 408}. Best is trial 48 with value: 237.0233154296875.
# [I 2023-03-17 11:42:09,813] Trial 49 finished with value: 241.18695068359375 and parameters: {'learning_rate': 0.0002054748132072813, 'optimizer': 'SGD', 'batch_size': 84, 'RL11': 275, 'RL21': 457, 'RL32': 42, 'RG012': 340, 'RG022': 425, 'RG112': 65, 'RG122': 111, 'CL12': 414, 'CL22': 446}. Best is trial 48 with value: 237.0233154296875.
# /tmp/ipykernel_499214/2219756517.py:37: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_x_and_t=pd.concat([t_data,x_data],1)
# [I 2023-03-17 11:44:07,808] A new study created in memory with name: no-name-5d28ebac-f4fd-4578-be79-60fa09963090
# # of files completed so far: 1
# /tmp/ipykernel_499214/830509479.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-17 11:45:01,680] Trial 0 finished with value: 238.45172119140625 and parameters: {'learning_rate': 5.6115164153345e-05, 'optimizer': 'Adam', 'batch_size': 157, 'RL11': 93, 'RL21': 93, 'RL32': 44, 'RG012': 446, 'RG022': 314, 'RG112': 367, 'RG122': 26, 'CL12': 498, 'CL22': 429}. Best is trial 0 with value: 238.45172119140625.
# [I 2023-03-17 11:46:04,194] Trial 1 finished with value: 240.7452392578125 and parameters: {'learning_rate': 2.6587543983272695e-05, 'optimizer': 'SGD', 'batch_size': 83, 'RL11': 276, 'RL21': 230, 'RL32': 160, 'RG012': 320, 'RG022': 85, 'RG112': 161, 'RG122': 198, 'CL12': 242, 'CL22': 406}. Best is trial 0 with value: 238.45172119140625.
# [I 2023-03-17 11:48:22,347] Trial 2 finished with value: 239.61236572265625 and parameters: {'learning_rate': 2.5081156860452307e-05, 'optimizer': 'SGD', 'batch_size': 19, 'RL11': 317, 'RL21': 100, 'RL32': 48, 'RG012': 487, 'RG022': 495, 'RG112': 417, 'RG122': 167, 'CL12': 64, 'CL22': 356}. Best is trial 0 with value: 238.45172119140625.
# [I 2023-03-17 11:51:51,923] Trial 3 finished with value: 237.30569458007812 and parameters: {'learning_rate': 7.591104805282687e-05, 'optimizer': 'SGD', 'batch_size': 16, 'RL11': 467, 'RL21': 144, 'RL32': 345, 'RG012': 170, 'RG022': 274, 'RG112': 287, 'RG122': 107, 'CL12': 497, 'CL22': 401}. Best is trial 3 with value: 237.30569458007812.
# [I 2023-03-17 11:52:49,638] Trial 4 finished with value: 276.5925598144531 and parameters: {'learning_rate': 0.0007568292060167617, 'optimizer': 'Adam', 'batch_size': 237, 'RL11': 59, 'RL21': 113, 'RL32': 38, 'RG012': 177, 'RG022': 209, 'RG112': 150, 'RG122': 427, 'CL12': 193, 'CL22': 155}. Best is trial 3 with value: 237.30569458007812.
because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:19:10,049] Trial 21 failed with value nan.
# [W 2023-03-17 12:20:44,857] Trial 22 failed with parameters: {'learning_rate': 0.00038410336575590284, 'optimizer': 'SGD', 'batch_size': 114, 'RL11': 413, 'RL21': 440, 'RL32': 383, 'RG012': 108, 'RG022': 330, 'RG112': 428, 'RG122': 262, 'CL12': 448, 'CL22': 199} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:20:44,857] Trial 22 failed with value nan.
# [W 2023-03-17 12:22:12,198] Trial 23 failed with parameters: {'learning_rate': 0.00045116838648987683, 'optimizer': 'SGD', 'batch_size': 110, 'RL11': 413, 'RL21': 443, 'RL32': 374, 'RG012': 113, 'RG022': 135, 'RG112': 442, 'RG122': 255, 'CL12': 424, 'CL22': 194} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:22:12,199] Trial 23 failed with value nan.
# [W 2023-03-17 12:23:41,422] Trial 24 failed with parameters: {'learning_rate': 0.0004197594673899007, 'optimizer': 'SGD', 'batch_size': 117, 'RL11': 420, 'RL21': 438, 'RL32': 380, 'RG012': 112, 'RG022': 325, 'RG112': 450, 'RG122': 276, 'CL12': 440, 'CL22': 192} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:23:41,423] Trial 24 failed with value nan.
# [W 2023-03-17 12:25:07,511] Trial 25 failed with parameters: {'learning_rate': 0.00046988249382592733, 'optimizer': 'SGD', 'batch_size': 110, 'RL11': 416, 'RL21': 448, 'RL32': 386, 'RG012': 104, 'RG022': 321, 'RG112': 436, 'RG122': 258, 'CL12': 444, 'CL22': 221} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:25:07,511] Trial 25 failed with value nan.
# [W 2023-03-17 12:26:38,636] Trial 26 failed with parameters: {'learning_rate': 0.0004898124951770981, 'optimizer': 'SGD', 'batch_size': 116, 'RL11': 418, 'RL21': 440, 'RL32': 381, 'RG012': 110, 'RG022': 326, 'RG112': 436, 'RG122': 266, 'CL12': 444, 'CL22': 217} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:26:38,637] Trial 26 failed with value nan.
# [W 2023-03-17 12:28:06,534] Trial 27 failed with parameters: {'learning_rate': 0.00046581811197635143, 'optimizer': 'SGD', 'batch_size': 111, 'RL11': 425, 'RL21': 439, 'RL32': 380, 'RG012': 109, 'RG022': 322, 'RG112': 446, 'RG122': 263, 'CL12': 439, 'CL22': 207} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:28:06,535] Trial 27 failed with value nan.
# [W 2023-03-17 12:29:38,237] Trial 28 failed with parameters: {'learning_rate': 0.0009870998098134745, 'optimizer': 'SGD', 'batch_size': 117, 'RL11': 420, 'RL21': 433, 'RL32': 379, 'RG012': 109, 'RG022': 329, 'RG112': 432, 'RG122': 247, 'CL12': 446, 'CL22': 200} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:29:38,238] Trial 28 failed with value nan.
# [W 2023-03-17 12:31:10,100] Trial 29 failed with parameters: {'learning_rate': 0.0004265415720458628, 'optimizer': 'SGD', 'batch_size': 114, 'RL11': 336, 'RL21': 442, 'RL32': 390, 'RG012': 103, 'RG022': 131, 'RG112': 458, 'RG122': 262, 'CL12': 454, 'CL22': 199} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:31:10,100] Trial 29 failed with value nan.
# [W 2023-03-17 12:32:40,859] Trial 30 failed with parameters: {'learning_rate': 0.00043590052395355597, 'optimizer': 'SGD', 'batch_size': 117, 'RL11': 412, 'RL21': 440, 'RL32': 376, 'RG012': 100, 'RG022': 330, 'RG112': 423, 'RG122': 263, 'CL12': 438, 'CL22': 192} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:32:40,860] Trial 30 failed with value nan.
# [W 2023-03-17 12:34:12,168] Trial 31 failed with parameters: {'learning_rate': 0.0003989209418248699, 'optimizer': 'SGD', 'batch_size': 116, 'RL11': 405, 'RL21': 438, 'RL32': 373, 'RG012': 80, 'RG022': 330, 'RG112': 439, 'RG122': 256, 'CL12': 441, 'CL22': 163} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:34:12,169] Trial 31 failed with value nan.
# [W 2023-03-17 12:35:37,783] Trial 32 failed with parameters: {'learning_rate': 0.0004100678828129935, 'optimizer': 'SGD', 'batch_size': 120, 'RL11': 327, 'RL21': 442, 'RL32': 379, 'RG012': 98, 'RG022': 335, 'RG112': 443, 'RG122': 256, 'CL12': 457, 'CL22': 191} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:35:37,783] Trial 32 failed with value nan.
# [W 2023-03-17 12:37:04,695] Trial 33 failed with parameters: {'learning_rate': 0.0003846257724496674, 'optimizer': 'SGD', 'batch_size': 111, 'RL11': 335, 'RL21': 441, 'RL32': 379, 'RG012': 101, 'RG022': 328, 'RG112': 446, 'RG122': 280, 'CL12': 436, 'CL22': 196} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:37:04,696] Trial 33 failed with value nan.
# [W 2023-03-17 12:38:30,510] Trial 34 failed with parameters: {'learning_rate': 0.0004130259890365946, 'optimizer': 'SGD', 'batch_size': 122, 'RL11': 413, 'RL21': 442, 'RL32': 362, 'RG012': 106, 'RG022': 334, 'RG112': 427, 'RG122': 252, 'CL12': 445, 'CL22': 192} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:38:30,511] Trial 34 failed with value nan.
# [W 2023-03-17 12:40:01,666] Trial 35 failed with parameters: {'learning_rate': 0.0004404009659246886, 'optimizer': 'SGD', 'batch_size': 118, 'RL11': 403, 'RL21': 445, 'RL32': 388, 'RG012': 107, 'RG022': 338, 'RG112': 439, 'RG122': 255, 'CL12': 396, 'CL22': 167} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:40:01,667] Trial 35 failed with value nan.
# [W 2023-03-17 12:41:23,817] Trial 36 failed with parameters: {'learning_rate': 0.0004337190962781237, 'optimizer': 'SGD', 'batch_size': 129, 'RL11': 322, 'RL21': 440, 'RL32': 386, 'RG012': 116, 'RG022': 341, 'RG112': 441, 'RG122': 266, 'CL12': 442, 'CL22': 199} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:41:23,818] Trial 36 failed with value nan.
# [W 2023-03-17 12:42:50,531] Trial 37 failed with parameters: {'learning_rate': 0.000466862293405412, 'optimizer': 'SGD', 'batch_size': 121, 'RL11': 417, 'RL21': 427, 'RL32': 385, 'RG012': 103, 'RG022': 329, 'RG112': 444, 'RG122': 266, 'CL12': 433, 'CL22': 171} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:42:50,532] Trial 37 failed with value nan.
# [W 2023-03-17 12:44:14,776] Trial 38 failed with parameters: {'learning_rate': 0.0004352239815003841, 'optimizer': 'SGD', 'batch_size': 112, 'RL11': 422, 'RL21': 448, 'RL32': 388, 'RG012': 108, 'RG022': 319, 'RG112': 440, 'RG122': 260, 'CL12': 447, 'CL22': 192} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:44:14,777] Trial 38 failed with value nan.
# [W 2023-03-17 12:45:42,698] Trial 39 failed with parameters: {'learning_rate': 0.0009866786803211986, 'optimizer': 'SGD', 'batch_size': 117, 'RL11': 404, 'RL21': 441, 'RL32': 368, 'RG012': 104, 'RG022': 324, 'RG112': 433, 'RG122': 262, 'CL12': 456, 'CL22': 189} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:45:42,699] Trial 39 failed with value nan.
# [W 2023-03-17 12:47:09,323] Trial 40 failed with parameters: {'learning_rate': 0.0004473556846712609, 'optimizer': 'SGD', 'batch_size': 125, 'RL11': 424, 'RL21': 444, 'RL32': 387, 'RG012': 115, 'RG022': 332, 'RG112': 418, 'RG122': 261, 'CL12': 440, 'CL22': 195} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:47:09,323] Trial 40 failed with value nan.
# [I 2023-03-17 12:48:38,221] Trial 41 finished with value: 241.10470581054688 and parameters: {'learning_rate': 0.00039528372310012396, 'optimizer': 'SGD', 'batch_size': 111, 'RL11': 326, 'RL21': 442, 'RL32': 384, 'RG012': 103, 'RG022': 332, 'RG112': 434, 'RG122': 269, 'CL12': 422, 'CL22': 211}. Best is trial 17 with value: 233.37863159179688.
# [I 2023-03-17 12:50:12,607] Trial 42 finished with value: 236.82080078125 and parameters: {'learning_rate': 0.0008499647054482835, 'optimizer': 'SGD', 'batch_size': 56, 'RL11': 419, 'RL21': 349, 'RL32': 510, 'RG012': 218, 'RG022': 134, 'RG112': 181, 'RG122': 133, 'CL12': 481, 'CL22': 504}. Best is trial 17 with value: 233.37863159179688.
# [W 2023-03-17 12:51:35,101] Trial 43 failed with parameters: {'learning_rate': 0.00039848451764591236, 'optimizer': 'SGD', 'batch_size': 112, 'RL11': 336, 'RL21': 337, 'RL32': 401, 'RG012': 127, 'RG022': 458, 'RG112': 464, 'RG122': 236, 'CL12': 435, 'CL22': 344} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:51:35,102] Trial 43 failed with value nan.
# [W 2023-03-17 12:53:04,033] Trial 44 failed with parameters: {'learning_rate': 0.00048557577837954097, 'optimizer': 'SGD', 'batch_size': 105, 'RL11': 315, 'RL21': 327, 'RL32': 413, 'RG012': 132, 'RG022': 446, 'RG112': 450, 'RG122': 225, 'CL12': 447, 'CL22': 191} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:53:04,034] Trial 44 failed with value nan.
# [W 2023-03-17 12:54:29,934] Trial 45 failed with parameters: {'learning_rate': 0.0004311078844019474, 'optimizer': 'SGD', 'batch_size': 123, 'RL11': 329, 'RL21': 458, 'RL32': 406, 'RG012': 69, 'RG022': 445, 'RG112': 459, 'RG122': 232, 'CL12': 438, 'CL22': 328} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:54:29,935] Trial 45 failed with value nan.
# [W 2023-03-17 12:56:00,458] Trial 46 failed with parameters: {'learning_rate': 0.00042122753649514837, 'optimizer': 'SGD', 'batch_size': 115, 'RL11': 333, 'RL21': 323, 'RL32': 393, 'RG012': 124, 'RG022': 445, 'RG112': 452, 'RG122': 236, 'CL12': 466, 'CL22': 213} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:56:00,459] Trial 46 failed with value nan.
# [W 2023-03-17 12:57:17,572] Trial 47 failed with parameters: {'learning_rate': 0.00042406491720808155, 'optimizer': 'SGD', 'batch_size': 115, 'RL11': 339, 'RL21': 458, 'RL32': 405, 'RG012': 137, 'RG022': 448, 'RG112': 83, 'RG122': 219, 'CL12': 450, 'CL22': 328} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:57:17,573] Trial 47 failed with value nan.
# [W 2023-03-17 12:58:36,563] Trial 48 failed with parameters: {'learning_rate': 0.00045875608914847153, 'optimizer': 'SGD', 'batch_size': 109, 'RL11': 320, 'RL21': 459, 'RL32': 405, 'RG012': 127, 'RG022': 448, 'RG112': 73, 'RG122': 239, 'CL12': 442, 'CL22': 344} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 12:58:36,563] Trial 48 failed with value nan.
# [W 2023-03-17 13:00:06,850] Trial 49 failed with parameters: {'learning_rate': 0.0004168279980253543, 'optimizer': 'SGD', 'batch_size': 120, 'RL11': 329, 'RL21': 475, 'RL32': 401, 'RG012': 133, 'RG022': 449, 'RG112': 459, 'RG122': 237, 'CL12': 450, 'CL22': 199} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 13:00:06,851] Trial 49 failed with value nan.
# /tmp/ipykernel_499214/2219756517.py:37: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_x_and_t=pd.concat([t_data,x_data],1)
# [I 2023-03-17 13:01:51,047] A new study created in memory with name: no-name-040883a4-1b94-47ac-9b1f-b29387a70628
# # of files completed so far: 2
# /tmp/ipykernel_499214/830509479.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-17 13:02:45,969] Trial 0 finished with value: 232.25872802734375 and parameters: {'learning_rate': 5.6115164153345e-05, 'optimizer': 'Adam', 'batch_size': 157, 'RL11': 93, 'RL21': 93, 'RL32': 44, 'RG012': 446, 'RG022': 314, 'RG112': 367, 'RG122': 26, 'CL12': 498, 'CL22': 429}. Best is trial 0 with value: 232.25872802734375.
# [I 2023-03-17 13:03:45,763] Trial 1 finished with value: 239.0474090576172 and parameters: {'learning_rate': 2.6587543983272695e-05, 'optimizer': 'SGD', 'batch_size': 83, 'RL11': 276, 'RL21': 230, 'RL32': 160, 'RG012': 320, 'RG022': 85, 'RG112': 161, 'RG122': 198, 'CL12': 242, 'CL22': 406}. Best is trial 0 with value: 232.25872802734375.
# [I 2023-03-17 13:06:03,413] Trial 2 finished with value: 233.95751953125 and parameters: {'learning_rate': 2.5081156860452307e-05, 'optimizer': 'SGD', 'batch_size': 19, 'RL11': 317, 'RL21': 100, 'RL32': 48, 'RG012': 487, 'RG022': 495, 'RG112': 417, 'RG122': 167, 'CL12': 64, 'CL22': 356}. Best is trial 0 with value: 232.25872802734375.
# [I 2023-03-17 13:08:43,619] Trial 3 finished with value: 233.40835571289062 and parameters: {'learning_rate': 7.591104805282687e-05, 'optimizer': 'SGD', 'batch_size': 16, 'RL11': 467, 'RL21': 144, 'RL32': 345, 'RG012': 170, 'RG022': 274, 'RG112': 287, 'RG122': 107, 'CL12': 497, 'CL22': 401}. Best is trial 0 with value: 232.25872802734375.
# [I 2023-03-17 13:09:21,018] Trial 4 finished with value: 299.545166015625 and parameters: {'learning_rate': 0.0007568292060167617, 'optimizer': 'Adam', 'batch_size': 237, 'RL11': 59, 'RL21': 113, 'RL32': 38, 'RG012': 177, 'RG022': 209, 'RG112': 150, 'RG122': 427, 'CL12': 193, 'CL22': 155}. Best is trial 0 with value: 232.25872802734375.
# [I 2023-03-17 13:11:18,995] Trial 5 finished with value: 230.83346557617188 and parameters: {'learning_rate': 0.00012172847081122418, 'optimizer': 'SGD', 'batch_size': 26, 'RL11': 506, 'RL21': 399, 'RL32': 114, 'RG012': 18, 'RG022': 421, 'RG112': 367, 'RG122': 378, 'CL12': 399, 'CL22': 52}. Best is trial 5 with value: 230.83346557617188.
because of the following error: The value nan is not acceptable..
# [W 2023-03-17 13:32:43,077] Trial 21 failed with value nan.
# [W 2023-03-17 13:33:53,907] Trial 22 failed with parameters: {'learning_rate': 0.0005844458487288985, 'optimizer': 'SGD', 'batch_size': 59, 'RL11': 512, 'RL21': 293, 'RL32': 245, 'RG012': 62, 'RG022': 148, 'RG112': 16, 'RG122': 396, 'CL12': 455, 'CL22': 94} because of the following error: The value nan is not acceptable..
# [W 2023-03-17 13:33:53,908] Trial 22 failed with value nan.
# [I 2023-03-17 13:35:25,598] Trial 23 finished with value: 246.54261779785156 and parameters: {'learning_rate': 0.0005249062074948539, 'optimizer': 'SGD', 'batch_size': 50, 'RL11': 506, 'RL21': 285, 'RL32': 508, 'RG012': 78, 'RG022': 154, 'RG112': 126, 'RG122': 394, 'CL12': 427, 'CL22': 321}. Best is trial 12 with value: 229.65771484375.
# [I 2023-03-17 13:37:17,862] Trial 24 finished with value: 231.05189514160156 and parameters: {'learning_rate': 0.00013447059619077639, 'optimizer': 'SGD', 'batch_size': 28, 'RL11': 496, 'RL21': 398, 'RL32': 117, 'RG012': 18, 'RG022': 429, 'RG112': 331, 'RG122': 374, 'CL12': 408, 'CL22': 69}. Best is trial 12 with value: 229.65771484375.
# [I 2023-03-17 13:38:58,863] Trial 25 finished with value: 230.50570678710938 and parameters: {'learning_rate': 9.983146979243465e-05, 'optimizer': 'SGD', 'batch_size': 71, 'RL11': 510, 'RL21': 466, 'RL32': 109, 'RG012': 59, 'RG022': 380, 'RG112': 419, 'RG122': 408, 'CL12': 457, 'CL22': 56}. Best is trial 12 with value: 229.65771484375.
# [I 2023-03-17 13:40:55,114] Trial 26 finished with value: 231.99169921875 and parameters: {'learning_rate': 0.00023254930189295174, 'optimizer': 'SGD', 'batch_size': 69, 'RL11': 439, 'RL21': 473, 'RL32': 228, 'RG012': 58, 'RG022': 367, 'RG112': 497, 'RG122': 415, 'CL12': 457, 'CL22': 104}. Best is trial 12 with value: 229.65771484375.
# [I 2023-03-17 13:42:18,034] Trial 27 finished with value: 235.56475830078125 and parameters: {'learning_rate': 9.740938254578531e-05, 'optimizer': 'SGD', 'batch_size': 106, 'RL11': 351, 'RL21': 476, 'RL32': 164, 'RG012': 154, 'RG022': 481, 'RG112': 295, 'RG122': 302, 'CL12': 459, 'CL22': 510}. Best is trial 12 with value: 229.65771484375.
# [I 2023-03-17 13:46:59,153] Trial 28 finished with value: 229.3724365234375 and parameters: {'learning_rate': 0.00018304038632682658, 'optimizer': 'SGD', 'batch_size': 8, 'RL11': 411, 'RL21': 391, 'RL32': 93, 'RG012': 57, 'RG022': 301, 'RG112': 454, 'RG122': 461, 'CL12': 512, 'CL22': 152}. Best is trial 28 with value: 229.3724365234375.
# ...
# [I 2023-03-18 08:33:10,351] Trial 4 finished with value: 287.8874206542969 and parameters: {'learning_rate': 0.0007568292060167617, 'optimizer': 'Adam', 'batch_size': 237, 'RL11': 59, 'RL21': 113, 'RL32': 38, 'RG012': 177, 'RG022': 209, 'RG112': 150, 'RG122': 427, 'CL12': 193, 'CL22': 155}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:35:11,968] Trial 5 finished with value: 243.81051635742188 and parameters: {'learning_rate': 0.00012172847081122418, 'optimizer': 'SGD', 'batch_size': 26, 'RL11': 506, 'RL21': 399, 'RL32': 114, 'RG012': 18, 'RG022': 421, 'RG112': 367, 'RG122': 378, 'CL12': 399, 'CL22': 52}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:36:05,752] Trial 6 finished with value: 256.6470947265625 and parameters: {'learning_rate': 5.211124595788268e-05, 'optimizer': 'SGD', 'batch_size': 163, 'RL11': 180, 'RL21': 47, 'RL32': 170, 'RG012': 177, 'RG022': 378, 'RG112': 332, 'RG122': 456, 'CL12': 250, 'CL22': 75}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:36:47,923] Trial 7 finished with value: 309.91314697265625 and parameters: {'learning_rate': 0.0002669866674274458, 'optimizer': 'Adam', 'batch_size': 199, 'RL11': 261, 'RL21': 275, 'RL32': 228, 'RG012': 28, 'RG022': 69, 'RG112': 31, 'RG122': 332, 'CL12': 172, 'CL22': 268}. Best is trial 0 with value: 242.47525024414062.
# [W 2023-03-18 08:37:38,271] Trial 8 failed with parameters: {'learning_rate': 0.0006533305220227731, 'optimizer': 'SGD', 'batch_size': 196, 'RL11': 129, 'RL21': 54, 'RL32': 160, 'RG012': 96, 'RG022': 478, 'RG112': 417, 'RG122': 330, 'CL12': 449, 'CL22': 415} because of the following error: The value nan is not acceptable..
# [W 2023-03-18 08:37:38,271] Trial 8 failed with value nan.
# [I 2023-03-18 08:38:36,277] Trial 9 finished with value: 243.11720275878906 and parameters: {'learning_rate': 2.3612399244412595e-05, 'optimizer': 'Adam', 'batch_size': 209, 'RL11': 461, 'RL21': 174, 'RL32': 70, 'RG012': 129, 'RG022': 228, 'RG112': 422, 'RG122': 443, 'CL12': 19, 'CL22': 269}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:40:33,315] Trial 10 finished with value: 281.6835632324219 and parameters: {'learning_rate': 6.83631406502272e-05, 'optimizer': 'Adam', 'batch_size': 92, 'RL11': 484, 'RL21': 176, 'RL32': 273, 'RG012': 365, 'RG022': 196, 'RG112': 498, 'RG122': 494, 'CL12': 141, 'CL22': 263}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:42:26,885] Trial 11 finished with value: 243.00567626953125 and parameters: {'learning_rate': 1.2150104649007388e-05, 'optimizer': 'Adam', 'batch_size': 136, 'RL11': 24, 'RL21': 456, 'RL32': 467, 'RG012': 499, 'RG022': 333, 'RG112': 182, 'RG122': 22, 'CL12': 373, 'CL22': 486}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:44:18,351] Trial 12 finished with value: 242.56192016601562 and parameters: {'learning_rate': 1.2473524935683992e-05, 'optimizer': 'Adam', 'batch_size': 140, 'RL11': 21, 'RL21': 508, 'RL32': 512, 'RG012': 495, 'RG022': 335, 'RG112': 194, 'RG122': 19, 'CL12': 382, 'CL22': 488}. Best is trial 0 with value: 242.47525024414062.
# [I 2023-03-18 08:46:03,793] Trial 13 finished with value: 241.7039031982422 and parameters: {'learning_rate': 1.101453210582588e-05, 'optimizer': 'Adam', 'batch_size': 162, 'RL11': 128, 'RL21': 339, 'RL32': 487, 'RG012': 413, 'RG022': 320, 'RG112': 255, 'RG122': 33, 'CL12': 509, 'CL22': 512}. Best is trial 13 with value: 241.7039031982422.
# [I 2023-03-18 09:13:55,221] Trial 31 finished with value: 243.25714111328125 and parameters: {'learning_rate': 1.4040600284283438e-05, 'optimizer': 'Adam', 'batch_size': 189, 'RL11': 364, 'RL21': 416, 'RL32': 480, 'RG012': 412, 'RG022': 16, 'RG112': 317, 'RG122': 176, 'CL12': 214, 'CL22': 134}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:15:33,257] Trial 32 finished with value: 241.21353149414062 and parameters: {'learning_rate': 1.6503385532725717e-05, 'optimizer': 'Adam', 'batch_size': 217, 'RL11': 391, 'RL21': 466, 'RL32': 503, 'RG012': 299, 'RG022': 293, 'RG112': 79, 'RG122': 126, 'CL12': 426, 'CL22': 227}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:16:59,378] Trial 33 finished with value: 245.72332763671875 and parameters: {'learning_rate': 3.078827432981507e-05, 'optimizer': 'Adam', 'batch_size': 250, 'RL11': 362, 'RL21': 478, 'RL32': 512, 'RG012': 302, 'RG022': 300, 'RG112': 58, 'RG122': 127, 'CL12': 508, 'CL22': 240}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:18:41,215] Trial 34 finished with value: 243.5430908203125 and parameters: {'learning_rate': 1.9845178274872245e-05, 'optimizer': 'Adam', 'batch_size': 157, 'RL11': 293, 'RL21': 379, 'RL32': 447, 'RG012': 344, 'RG022': 303, 'RG112': 137, 'RG122': 211, 'CL12': 467, 'CL22': 299}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:19:57,404] Trial 35 finished with value: 246.53445434570312 and parameters: {'learning_rate': 2.4248468372652124e-05, 'optimizer': 'SGD', 'batch_size': 221, 'RL11': 449, 'RL21': 433, 'RL32': 486, 'RG012': 284, 'RG022': 354, 'RG112': 67, 'RG122': 85, 'CL12': 415, 'CL22': 205}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:21:23,943] Trial 36 finished with value: 243.68295288085938 and parameters: {'learning_rate': 1.5093142439232722e-05, 'optimizer': 'Adam', 'batch_size': 198, 'RL11': 389, 'RL21': 478, 'RL32': 369, 'RG012': 468, 'RG022': 250, 'RG112': 105, 'RG122': 163, 'CL12': 367, 'CL22': 375}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:22:29,163] Trial 37 finished with value: 246.4945068359375 and parameters: {'learning_rate': 2.898529527914872e-05, 'optimizer': 'SGD', 'batch_size': 173, 'RL11': 246, 'RL21': 312, 'RL32': 413, 'RG012': 208, 'RG022': 279, 'RG112': 171, 'RG122': 115, 'CL12': 482, 'CL22': 145}. Best is trial 21 with value: 240.61419677734375.
# [I 2023-03-18 09:23:35,165] Trial 38 finished with value: 240.28262329101562 and parameters: {'learning_rate': 1.2356168476803406e-05, 'optimizer': 'Adam', 'batch_size': 231, 'RL11': 323, 'RL21': 390, 'RL32': 325, 'RG012': 121, 'RG022': 398, 'RG112': 361, 'RG122': 44, 'CL12': 280, 'CL22': 98}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:24:37,899] Trial 39 finished with value: 254.02972412109375 and parameters: {'learning_rate': 1.0625279771632584e-05, 'optimizer': 'SGD', 'batch_size': 238, 'RL11': 315, 'RL21': 431, 'RL32': 441, 'RG012': 94, 'RG022': 511, 'RG112': 383, 'RG122': 44, 'CL12': 138, 'CL22': 77}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:25:26,340] Trial 40 finished with value: 242.93063354492188 and parameters: {'learning_rate': 1.2967216762777154e-05, 'optimizer': 'Adam', 'batch_size': 209, 'RL11': 212, 'RL21': 260, 'RL32': 165, 'RG012': 106, 'RG022': 447, 'RG112': 461, 'RG122': 38, 'CL12': 91, 'CL22': 104}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:26:14,101] Trial 41 finished with value: 254.74319458007812 and parameters: {'learning_rate': 1.0012066785283433e-05, 'optimizer': 'SGD', 'batch_size': 230, 'RL11': 142, 'RL21': 389, 'RL32': 213, 'RG012': 66, 'RG022': 404, 'RG112': 354, 'RG122': 71, 'CL12': 265, 'CL22': 18}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:27:24,947] Trial 42 finished with value: 241.77938842773438 and parameters: {'learning_rate': 1.8653574618856636e-05, 'optimizer': 'Adam', 'batch_size': 191, 'RL11': 342, 'RL21': 365, 'RL32': 300, 'RG012': 192, 'RG022': 350, 'RG112': 287, 'RG122': 148, 'CL12': 231, 'CL22': 249}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:28:43,019] Trial 43 finished with value: 242.85708618164062 and parameters: {'learning_rate': 2.341401072287174e-05, 'optimizer': 'Adam', 'batch_size': 152, 'RL11': 284, 'RL21': 346, 'RL32': 337, 'RG012': 149, 'RG022': 303, 'RG112': 278, 'RG122': 105, 'CL12': 235, 'CL22': 239}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:29:57,275] Trial 44 finished with value: 241.28897094726562 and parameters: {'learning_rate': 1.3109513013359974e-05, 'optimizer': 'Adam', 'batch_size': 246, 'RL11': 437, 'RL21': 417, 'RL32': 237, 'RG012': 166, 'RG022': 350, 'RG112': 399, 'RG122': 375, 'CL12': 189, 'CL22': 290}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:31:12,363] Trial 45 finished with value: 241.06915283203125 and parameters: {'learning_rate': 1.3076475278545437e-05, 'optimizer': 'Adam', 'batch_size': 251, 'RL11': 506, 'RL21': 461, 'RL32': 242, 'RG012': 158, 'RG022': 317, 'RG112': 393, 'RG122': 385, 'CL12': 172, 'CL22': 291}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:32:27,451] Trial 46 finished with value: 241.32948303222656 and parameters: {'learning_rate': 1.3446168420144541e-05, 'optimizer': 'Adam', 'batch_size': 246, 'RL11': 511, 'RL21': 480, 'RL32': 236, 'RG012': 137, 'RG022': 200, 'RG112': 397, 'RG122': 385, 'CL12': 156, 'CL22': 293}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:33:42,597] Trial 47 finished with value: 240.3099365234375 and parameters: {'learning_rate': 1.3015805955282056e-05, 'optimizer': 'Adam', 'batch_size': 228, 'RL11': 475, 'RL21': 457, 'RL32': 189, 'RG012': 159, 'RG022': 274, 'RG112': 438, 'RG122': 375, 'CL12': 110, 'CL22': 278}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:34:50,016] Trial 48 finished with value: 242.64715576171875 and parameters: {'learning_rate': 1.5697202877211564e-05, 'optimizer': 'Adam', 'batch_size': 229, 'RL11': 473, 'RL21': 454, 'RL32': 112, 'RG012': 52, 'RG022': 253, 'RG112': 464, 'RG122': 345, 'CL12': 94, 'CL22': 325}. Best is trial 38 with value: 240.28262329101562.
# [I 2023-03-18 09:36:07,501] Trial 49 finished with value: 243.95870971679688 and parameters: {'learning_rate': 2.216804907208182e-05, 'optimizer': 'Adam', 'batch_size': 205, 'RL11': 493, 'RL21': 508, 'RL32': 183, 'RG012': 109, 'RG022': 282, 'RG112': 444, 'RG122': 421, 'CL12': 20, 'CL22': 368}. Best is trial 38 with value: 240.28262329101562.
# # of files completed so far: 20

# %%
print(np.mean(pehe_total))
# Out:
# nan

# %%
pehe_total
# Out:
# [0.32149946689605713,
#  0.31149980425834656,
#  0.33012479543685913,
#  0.3283536434173584,
#  0.3182544410228729,
#  0.3404625654220581,
#  0.3272532820701599,
#  0.29819491505622864,
#  0.30554065108299255,
#  0.3159219026565552,
#  nan,
#  0.31198298931121826,
#  0.3216995298862457,
#  0.3395161032676697,
#  0.3155890703201294,
#  0.3060864210128784,
#  0.34267354011535645,
#  0.32114407420158386,
#  0.30718937516212463,
#  0.3327989876270294]

# %%
np.savetxt("Ours1_10_(twins_Hyper_val_300ep_intsample).csv", pehe_total,delimiter =", ", fmt ='% s')

# %%
#concate_pred,d_out,phi=model()

data_orig=data.iloc[:,5:30]
labels=data.iloc[:,0]

# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result = tsne.fit_transform(data_orig) #combined_features combined_transformed
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'label': labels})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df, ax=ax,s=120)
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

# %%
data_for_trans=data.iloc[:,5:30]
labels_for_trans=data.iloc[:,0]

data_tensor=torch.from_numpy(data_for_trans.to_numpy().astype(np.float32))
concate_pred,d_out,phi=model(data_tensor,0.5)

#data=data[:,5:30]
#labels=data[:,0]

# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result = tsne.fit_transform(phi.detach().cpu().numpy()) #combined_features combined_transformed
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'label': labels_for_trans})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df, ax=ax,s=120)
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

# %%
plt.plot(train_loss, label='Regression loss on training')
plt.plot(val_loss, label='Regression loss on validation')
plt.legend()
plt.show()

# %%
plt.plot(train_tloss,label='Cross entropy loss of treatment classifier on training')
plt.plot(val_tloss,label='Cross entropy loss of treatment classifier on validation')
plt.legend()
plt.show()

# %%
'''
full network origional with optuna

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], params['CL22']), #
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,d_out

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None




def objective(trial,i):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 512),
          'RL21': trial.suggest_int('RL21', 16, 512),
          'RL32': trial.suggest_int('RL32', 16, 512),
          'RG012':trial.suggest_int('RG012', 16, 512),
        'RG022':trial.suggest_int('RG022', 16, 512),
        'RG112':trial.suggest_int('RG112', 16, 512),
        'RG122':trial.suggest_int('RG122', 16, 512),
        'CL12':trial.suggest_int('CL12', 16, 512),
        'CL22':trial.suggest_int('CL22', 16, 512)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i)

    return pehe


'''
# Out:
# '\nfull network origional with optuna\n\nclass TarNet(nn.Module):\n    def __init__(self,params):\n        super(TarNet, self).__init__()\n        self.encoder1 = nn.Linear(25, params[\'RL11\'])\n        self.encoder2 = nn.Linear(params[\'RL11\'], params[\'RL21\'])\n        self.encoder3 = nn.Linear(params[\'RL21\'], params[\'RL32\'])\n        \n        self.dis1_d = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'CL12\']), #params[\'CL12\']\n            nn.ReLU(),\n            nn.Dropout(p=0.1)\n        )\n        self.dis2_d = nn.Sequential(\n            nn.Linear(params[\'CL12\'], params[\'CL22\']), #\n            nn.ReLU(),\n            nn.Dropout(p=.01)\n        )\n        \n        self.dis3_d = nn.Sequential(\n            nn.Linear(params[\'CL22\'], 2),\n            nn.ReLU(),\n            nn.Dropout(p=.01)\n        )\n       \n        \n        self.regressor1_y0 = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'RG012\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressor2_y0 = nn.Sequential(\n            nn.Linear(params[\'RG012\'], params[\'RG022\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressorO_y0 = nn.Linear(params[\'RG022\'], 1)\n\n        self.regressor1_y1 = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'RG112\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressor2_y1 = nn.Sequential(\n            nn.Linear(params[\'RG112\'], params[\'RG122\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressorO_y1 = nn.Linear(params[\'RG122\'], 1)\n\n\n\n    def forward(self, inputs,alpha=0.5):\n        x = nn.functional.elu(self.encoder1(inputs))\n        phi= nn.functional.elu(self.encoder2(x))\n        phi = nn.functional.elu(self.encoder3(phi))\n        \n        out_y0 = self.regressor1_y0(phi)\n        out_y0 = self.regressor2_y0(out_y0)\n        y0 = self.regressorO_y0(out_y0)\n\n        out_y1 = self.regressor1_y1(phi)\n        out_y1 = self.regressor2_y1(out_y1)\n        y1 = self.regressorO_y1(out_y1)\n\n        concat = torch.cat((y0, y1), 1)\n        \n        rev = ReverseLayerF.apply(phi, alpha)\n        \n        out_d1 = self.dis1_d(rev)\n        out_d2 = self.dis2_d(out_d1)\n        d_out = self.dis3_d(out_d2)\n\n        concat = torch.cat((y0, y1), 1)\n        return concat,d_out\n\nclass ReverseLayerF(Function):\n    @staticmethod\n    def forward(ctx, x, alpha):\n        ctx.alpha = alpha\n\n        return x.view_as(x)\n\n    @staticmethod\n    def backward(ctx, grad_output):\n        output = grad_output.neg() * ctx.alpha\n\n        return output, None\n    \nclass GRL(Function):\n    @staticmethod\n    def forward(ctx, tensor, constant):\n        ctx.constant = constant\n        return tensor * constant\n    @staticmethod\n    def backward(ctx, grad_output):\n        return grad_output.neg() * ctx.constant, None\n\n\n\n\ndef objective(trial,i):\n\n    params = {\n          \'learning_rate\': trial.suggest_loguniform(\'learning_rate\', 1e-5, 1e-3),\n          \'optimizer\': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),\n          \'batch_size\':trial.suggest_int(\'batch_size\', 8, 256),\n          \'RL11\':trial.suggest_int(\'RL11\', 16, 512),\n          \'RL21\': trial.suggest_int(\'RL21\', 16, 512),\n          \'RL32\': trial.suggest_int(\'RL32\', 16, 512),\n          \'RG012\':trial.suggest_int(\'RG012\', 16, 512),\n        \'RG022\':trial.suggest_int(\'RG022\', 16, 512),\n        \'RG112\':trial.suggest_int(\'RG112\', 16, 512),\n        \'RG122\':trial.suggest_int(\'RG122\', 16, 512),\n        \'CL12\':trial.suggest_int(\'CL12\', 16, 512),\n        \'CL22\':trial.suggest_int(\'CL22\', 16, 512)\n          \n          }\n\n    model = TarNet(params)\n\n    pehe,model= train_evaluate(params, model, trial,i)\n\n    return pehe\n\n\n'

# %%
'''
Library way: all networks have two layers 
1.38

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL21'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL21'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], 1),#params['RG022']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL21'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], 1), #params['RG122']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        #phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        #y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        #y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((out_y0, out_y1), 1)
        return concat,out_d2

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

'''

# %%
'''
Tutorial way: layers and neurons all changed

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], params['CL22']), #
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], 1), #params['RG022']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], 1), #params['RG122']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        #phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        #y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        #y1 = self.regressorO_y1(out_y1)

        concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        d_out = self.dis3_d(out_d2)

        concat = torch.cat((out_y0, out_y1), 1)
        return concat,d_out

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None




def objective(trial,i):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 32),
          'RL21': trial.suggest_int('RL21', 16, 32),
          'RL32': trial.suggest_int('RL32', 16, 32),
          'RG012':trial.suggest_int('RG012', 16, 32),
        'RG022':trial.suggest_int('RG022', 16, 32),
        'RG112':trial.suggest_int('RG112', 16, 32),
        'RG122':trial.suggest_int('RG122', 16, 32),
        'CL12':trial.suggest_int('CL12', 16, 32),
        'CL22':trial.suggest_int('CL22', 16, 32)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i)

    return pehe


'''

# %%
'''
result 0.71 seed=42, result 0.79 seed=0, result 0.72 seed=1
one change: with 2 layers of classifier

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,out_d2

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None


'''
