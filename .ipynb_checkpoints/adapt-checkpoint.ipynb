# %%
from sklearn.linear_model import RidgeClassifier
from adapt.utils import make_classification_da
from adapt.feature_based import CORAL
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn import datasets, linear_model
from sklearn import svm
from sklearn.metrics import mean_squared_error, r2_score

# %%
def get_data(data_type,file_num):

    if(data_type=='train'):
        data=pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_train_{file_num}.csv")
        #data=pd.read_csv(f"Data/ihdp_npci_train_{file_num}.csv",index_col=False)
    else:
        data = pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_test_{file_num}.csv")
        #data = pd.read_csv(f"Data/ihdp_npci_test_{file_num}.csv",index_col=False)

    x_data=pd.concat([data.iloc[:,0], data.iloc[:, 1:30]], axis = 1)
 
   
    y_data=data.iloc[:, 1]
    
    return x_data,y_data

# %%
reg_0 = svm.SVR()
reg_1=svm.SVR()

# %%
def cal_pehe(y_1,y_0,test_x):
    #pehe...
    cate_pred=y_1-y_0
    #cate_pred=y1-y0
    cate_true=test_x.iloc[:,4]-test_x.iloc[:,3] #Hill's noiseless true values
    cate_err=np.mean( np.square( ( (cate_true) - (cate_pred) ) ) )
    return np.sqrt(cate_err)

def coral(xs,xt):
    model = CORAL(linear_model.LinearRegression(), Xt=x_train_tr.iloc[:,5:30], random_state=0,verbose=0)
    trans=model.fit_transform(xs,xt)
    return trans
def main_func(fil_num):
    x_data,y_data=get_data('train',fil_num)
    test_x,test_y=get_data('test',fil_num)
    x_train_sr=x_data[x_data['treatment']==0]
    y_train_sr=y_data[x_data['treatment']==0]
    x_train_tr=x_data[x_data['treatment']==1]
    y_train_tr=y_data[x_data['treatment']==1]
    
    #--------------
    trans=coral(x_train_sr.iloc[:,5:30],x_train_tr.iloc[:,5:30])
    
    reg_0.fit(trans, y_train_sr)
    y_0=reg_0.predict(test_x.iloc[:,5:30])
    reg_1.fit(x_train_tr.iloc[:,5:30], y_train_tr)
    y_1=reg_1.predict(test_x.iloc[:,5:30])
    
    pehe=cal_pehe(y_1,y_0,test_x)
    return pehe

# %%
pehe_list=[]
for i in range(1,100):
    pehe_list.append(main_func(i))
# Out:
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# /home/ahmad/envs/RL/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(

# %%
print(np.mean(pehe_list))
# Out:
# 1.235129931459514

# %%
pehe_list
# Out:
# [0.8473901797385537,
#  0.7669099423017512,
#  0.707052957732689,
#  0.4936358437737789,
#  1.2038718601358298,
#  1.995240191920462,
#  0.348889595429239,
#  0.5410177180176383,
#  1.4427635051763266,
#  2.39116374373201,
#  1.1666048938452627,
#  0.44980412051306584,
#  0.5909118826217487,
#  1.3655993245933629,
#  2.3618664766916817,
#  0.9088483708644111,
#  0.45827789800685015,
#  0.34747516655732635,
#  0.953386170031038,
#  1.332878480034394,
#  0.8943412395585745,
#  0.5264382300139551,
#  0.491674620180354,
#  0.6601045389799556,
#  0.6179262663163018,
#  0.9884170402939745,
#  1.0601683171693688,
#  0.739719135662366,
#  2.8952954884326276,
#  0.5354698432714597,
#  0.4507546020229546,
#  0.44835179921474855,
#  0.5942396881856294,
#  0.5853882854087893,
#  0.5938386347959671,
#  0.5840357552801695,
#  0.7068390276021315,
#  0.4805079323397699,
#  1.1953212446743993,
#  3.2299557264489955,
#  1.724440181641129,
#  0.6032955218012015,
#  0.44460453718689413,
#  1.4920873917572648,
#  0.49176748991494174,
#  0.517319517711161,
#  0.5959586796748667,
#  1.9287485904135013,
#  3.9485870466183424,
#  5.215765334210645,
#  1.0206629385702433,
#  0.42083656628304644,
#  0.4245463512105616,
#  3.0861537094604965,
#  0.5136378581831174,
#  1.5602252299318276,
#  0.42263937025517606,
#  3.7665659975503445,
#  0.48020162119566673,
#  0.48431335492103733,
#  0.5976719581869769,
#  0.5151780359820166,
#  0.6973521854655568,
#  0.552158985602762,
#  0.5574040969065335,
#  0.646261403678141,
#  2.1633698790690015,
#  0.5077262163607007,
#  2.015648795849662,
#  1.269421340856975,
#  4.332068178835677,
#  1.3247890997647394,
#  2.0903492671667396,
#  0.7065783509886167,
#  1.7231292183571494,
#  0.9603564835813045,
#  0.839080027375299,
#  1.1184456861233987,
#  2.06302228920785,
#  3.573963829581274,
#  0.5500948949339178,
#  3.8849428109999082,
#  0.7879271890276677,
#  1.4820722691823074,
#  0.3665922221497404,
#  1.0077293409841228,
#  0.48302225768670126,
#  5.722452976459957,
#  1.746651176749856,
#  0.5435154588999161,
#  0.7641773713581419,
#  0.429499749714393,
#  0.4404638042694013,
#  0.6191331914405929,
#  0.9446958126062552,
#  3.5143566501103902,
#  1.0919550689337145,
#  0.7846903665187765,
#  0.7651822474643828]
