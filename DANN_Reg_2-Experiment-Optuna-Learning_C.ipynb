# %%
import numpy as np
import pandas as pd
import random
import os
import gc
import math
import optuna
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.manifold import TSNE
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch import optim
from geomloss import SamplesLoss
from torch.autograd import Function
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.nn.functional import normalize
#from torchmetrics.classification import BinaryAccuracyS
from torchmetrics.classification import BinaryF1Score,BinaryAccuracy
from torchmetrics import R2Score
from sklearn.preprocessing import StandardScaler
#import torch.linalg as linalg
torch.manual_seed(42)

# %%
class Data(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X.astype(np.float32))
        self.y = torch.from_numpy(y.astype(np.float32))
        self.len = self.X.shape[0]
       
    def __getitem__(self, index):
        return self.X[index], self.y[index]
   
    def __len__(self):
        return self.len

# %%
def get_data(data_type,file_num):

    if(data_type=='train'):
        data=pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_train_{file_num}.csv")
        #data=pd.read_csv(f"Data/ihdp_npci_train_{file_num}.csv",index_col=False)
    else:
        data = pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_test_{file_num}.csv")
        #data = pd.read_csv(f"Data/ihdp_npci_test_{file_num}.csv",index_col=False)

    x_data=pd.concat([data.iloc[:,0], data.iloc[:, 1:30]], axis = 1)
 
   
    y_data=data.iloc[:, 1]
   
    
    return x_data,y_data

# %%
def get_data_2(data_type,file_num):

    if(data_type=='train'):
        #data=pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_train_{file_num}.csv")
        data=pd.read_csv(f"Data/ihdp_npci_train_{file_num}.csv",index_col=False)
    else:
        #data = pd.read_csv(f"Dataset/IHDP_a/ihdp_npci_test_{file_num}.csv")
        data = pd.read_csv(f"Data/ihdp_npci_test_{file_num}.csv",index_col=False)

   
    x_data=data
  
    del x_data[x_data.columns[0]]
   
    y_data=data.iloc[:, 1]
    
    return x_data,y_data

# %%
def get_dataloader(x_data,y_data,batch_size):

    x_train_sr=x_data[x_data['treatment']==0]
    y_train_sr=y_data[x_data['treatment']==0]
    x_train_tr=x_data[x_data['treatment']==1]
    y_train_tr=y_data[x_data['treatment']==1]


    train_data_sr = Data(np.array(x_train_sr), np.array(y_train_sr))
    train_dataloader_sr = DataLoader(dataset=train_data_sr, batch_size=batch_size)

    train_data_tr = Data(np.array(x_train_tr), np.array(y_train_tr))
    train_dataloader_tr = DataLoader(dataset=train_data_tr, batch_size=batch_size)


    return train_dataloader_sr, train_dataloader_tr

# %%
def regression_loss(concat_true, concat_pred):
    #computes a standard MSE loss for TARNet
    y_true = concat_true[:, 0] #get individual vectors
    t_true = concat_true[:, 1]

    y0_pred = concat_pred[:, 0]
    y1_pred = concat_pred[:, 1]

    #Each head outputs a prediction for both potential outcomes
    #We use t_true as a switch to only calculate the factual loss
    loss0 = torch.sum((1. - t_true) * torch.square(y_true - y0_pred))
    loss1 = torch.sum(t_true * torch.square(y_true - y1_pred))
    #note Shi uses tf.reduce_sum for her losses instead of tf.reduce_mean.
    #They should be equivalent but it's possible that having larger gradients accelerates convergence.
    #You can always try changing it!
    return loss0 + loss1

# %%
def cal_mmd(x, y, sigma):
    # compare kernel MMD paper and code:
    # A. Gretton et al.: A kernel two-sample test, JMLR 13 (2012)
    # http://www.gatsby.ucl.ac.uk/~gretton/mmd/mmd.htm
    # x shape [n, d] y shape [m, d]
    # n_perm number of bootstrap permutations to get p-value, pass none to not get p-value
    n, d = x.shape
    m, d2 = y.shape
    assert d == d2
    xy = torch.cat([x.detach(), y.detach()], dim=0)
    dists = torch.cdist(xy, xy, p=2.0)
    # we are a bit sloppy here as we just keep the diagonal and everything twice
    # note that sigma should be squared in the RBF to match the Gretton et al heuristic
    k = torch.exp((-1/(2*sigma**2)) * dists**2) + torch.eye(n+m)*1e-5
    k_x = k[:n, :n]
    k_y = k[n:, n:]
    k_xy = k[:n, n:]
    # The diagonals are always 1 (up to numerical error, this is (3) in Gretton et al.)
    # note that their code uses the biased (and differently scaled mmd)
    mmd = k_x.sum() / (n * (n - 1)) + k_y.sum() / (m * (m - 1)) - 2 * k_xy.sum() / (n * m)
    return mmd

# %%
def loss_cal(X_data,y_data,net,alpha):
    b_accu = BinaryAccuracy()
    b_f1=BinaryF1Score()
    r2score = R2Score()

    
    x_train_sr=X_data[X_data['treatment']==0]
    y_train_sr=y_data[X_data['treatment']==0]
    x_train_tr=X_data[X_data['treatment']==1]
    y_train_tr=y_data[X_data['treatment']==1]
    xs_t=x_train_sr.iloc[:,0].to_numpy()
    xt_t=x_train_tr.iloc[:,0].to_numpy()
    
    
    xs=x_train_sr.iloc[:,5:30].to_numpy()
    xt=x_train_tr.iloc[:,5:30].to_numpy()
    xs_t=torch.from_numpy(xs_t.astype(np.float32))
    xt_t=torch.from_numpy(xt_t.astype(np.float32))
    y_train_sr=y_train_sr.to_numpy()
    y_train_tr=y_train_tr.to_numpy()
    xs=torch.from_numpy(xs.astype(np.float32))
    xt=torch.from_numpy(xt.astype(np.float32))
    
    y_train_sr=torch.from_numpy(y_train_sr.astype(np.float32))
    y_train_tr=torch.from_numpy(y_train_tr.astype(np.float32))
    
    
    input_data=torch.cat((xs,xt),0)
    true_y=torch.unsqueeze(torch.cat((y_train_sr,y_train_tr),0), dim=1)
    true_t=torch.unsqueeze(torch.cat((xs_t,xt_t),0), dim=1)
    
    
    concat_true=torch.cat((true_y,true_t),1)
    concat_pred,d_out,phi=net(input_data,alpha)
    loss=regression_loss(concat_true, concat_pred)
    rs=-1
    ipm=-1
    
    if(model_found==True):
 
        preds=torch.gather(input=concat_pred,dim= 1,index=true_t.type(torch.int64))
        rs=r2score(preds, true_y).item()
        x=phi[0:xs.shape[0],:]
        y=phi[xs.shape[0]:,:]
        ipm=cal_mmd(x,y,.01)
        '''
        if(x.shape[0]<y.shape[0]):
            y=y[0:x.shape[0],:]
        else:
             x=x[0:y.shape[0],:]
        
        
        loss1 = SamplesLoss(loss="sinkhorn", p=2, blur=.05)
        los = loss1(x,y)
        ipm=los.item()
        '''
        

    
    #was_distance=-1
    #if(model_found==True):
    #   tsne_result_tr=cal_TSNE(phi)

    #    # wasserstein distance
     #   loss1 = SamplesLoss(loss="sinkhorn", p=2, blur=.05)
      #  t_zero_tr=tsne_result_tr[:,0]
       # t_one_tr=tsne_result_tr[:,1]
        #wasser_tr = loss1(torch.unsqueeze(torch.from_numpy(t_zero_tr.astype(np.float32)),dim=1),torch.unsqueeze(torch.from_numpy(t_one_tr.astype(np.float32)),dim=1))
       # was_distance=wasser_tr.item()
        
    
    
    t_actual=torch.cat((xs_t.type(torch.LongTensor),xt_t.type(torch.LongTensor)),0)
    
    domain_loss=criterion(d_out, t_actual)
    
    predicted = torch.argmax(d_out, dim=1)
    
    
    
    
    return rs,ipm,domain_loss.item(),loss.item(),b_accu(predicted, t_actual.squeeze()),b_f1(predicted, t_actual.squeeze())

# %%
def cal_TSNE(phi):
    n_components = 2
    tsne = TSNE(n_components,random_state=42)
    tsne_result_tr = tsne.fit_transform(phi.detach().cpu().numpy())
    
    return tsne_result_tr

# %%
def objective(trial,i):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 512),
          'RL21': trial.suggest_int('RL21', 16, 512),
          'RL32': trial.suggest_int('RL32', 16, 512),
          'RG012':trial.suggest_int('RG012', 16, 512),
        'RG022':trial.suggest_int('RG022', 16, 512),
        'RG112':trial.suggest_int('RG112', 16, 512),
        'RG122':trial.suggest_int('RG122', 16, 512),
        'CL12':trial.suggest_int('CL12', 16, 512),
        'CL22':trial.suggest_int('CL22', 16, 512)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i)

    return pehe

# %%
def pehe_loss_2(y1_pred,y0_pred,mu_1,mu_0):
    a=((mu_1-mu_0)-(y1_pred-y0_pred))
    er1=torch.square(a)
    #pehe=torch.mean(er1)
    pehe=torch.sqrt(torch.mean(er1))
    return pehe

# %%
# PEHE evaluation
def cal_pehe(data,y,model, alpha=0.5):
    #data,y=get_data('test',i)

    data=data.to_numpy()
    data=torch.from_numpy(data.astype(np.float32))



    concat_pred,d_out,phi=model(data[:,5:30])
    #dont forget to rescale the outcome before estimation!
    #y0_pred = data['y_scaler'].inverse_transform(concat_pred[:, 0].reshape(-1, 1))
    #y1_pred = data['y_scaler'].inverse_transform(concat_pred[:, 1].reshape(-1, 1))
    #y0=scaler.inverse_transform(concat_pred[:,0].reshape(-1, 1))
    #y1=scaler.inverse_transform(concat_pred[:,1].reshape(-1, 1))
    cate_pred=concat_pred[:,1]-concat_pred[:,0]
    #cate_pred=y1-y0
    
    cate_true=data[:,4]-data[:,3] #Hill's noiseless true values


    cate_err=torch.mean( torch.square( ( (cate_true) - (cate_pred) ) ) )

    return torch.sqrt(cate_err).item()

# %%
def cal_pehe_nn(data,y,model, alpha=0.5):
        
        datat=data.to_numpy()
        datat=torch.from_numpy(datat.astype(np.float32))
        df_datac=data[data['treatment']==0]
        df_datat=data[data['treatment']==1]
        
        concat_pred,d_out,phi=model(datat[:,5:30])
        PhiC, PhiT = torch.split(phi, [torch.sum(datat[:,0] == 0), torch.sum(datat[:,0] == 1)], dim=0)
        dists = torch.sqrt(torch.cdist(PhiC, PhiT))
        
        c_index=torch.argmin(dists, dim=0).tolist()
        t_index=torch.argmin(dists, dim=1).tolist()
    
        yT_nn=df_datac.iloc[c_index]['y_factual']
        yC_nn=df_datat.iloc[t_index]['y_factual']
        yT_nn=yT_nn.to_numpy()
        yT_nn=torch.from_numpy(yT_nn.astype(np.float32))
        yC_nn=yC_nn.to_numpy()
        yC_nn=torch.from_numpy(yC_nn.astype(np.float32))
        y_nn = torch.cat([yT_nn, yC_nn],0) 
        
        
        
        
        y=y.to_numpy()
        y=torch.from_numpy(y.astype(np.float32))
        

        
        cate_nn_err=torch.sqrt(torch.mean(torch.square((1 - 2 * datat[:,0]) * (y_nn - y) - (concat_pred[:,1] - concat_pred[:,0]))))
        return cate_nn_err
        #torch.mean( torch.square( (1-2*datat[:,0]) * (y_nn-y) - (concat_pred[:,1]-concat_pred[:,0]) ) )

# %%
class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,out_d2,phi

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
epochs=300
#batch_size=32
criterion = nn.CrossEntropyLoss()
#criterion =nn.BCELoss()

# %%
train_loss=[]
val_loss=[]
train_accu=[]
val_accu=[]
val_f1=[]
train_f1=[]
train_tloss=[]
val_tloss=[]
train_wass=[]
val_wass=[]
tr_r2=[]
val_r2=[]
d_loss=[]
pehe_error=[]
#num_files=2
def train_evaluate(param, model, trial,file_num):
    #for nf in range(1,num_files):
    x_data,y_data=get_data('train',file_num)
    X_train, X_val,y_train, y_val = train_test_split(x_data,y_data ,
                                       random_state=42, 
                                       test_size=0.27)
    
    
    
    #net=TarNet(25,.01)
    #opt_net = torch.optim.Adam(net.parameters(), lr=1e-4)
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
    
    optimizer = getattr(optim, param['optimizer'])(model.parameters(), lr= param['learning_rate'])
    
    if use_cuda:

        #model = model.cuda()
        model = model
        #criterion = criterion
  

    for ep in range(1,epochs+1 ):
        
        lamda_max=5
        e0=20
        train_dataloader_sr, train_dataloader_tr=get_dataloader(X_train,y_train,param['batch_size'])
        
        
        lambda_val=(lamda_max)*((ep-e0)/(epochs-e0))
        alpha=max(0,lambda_val)
        dis_loss=0
        total_loss=0
        reg_los=0
 
        for batch_idx, (train_source_data, train_target_data) in enumerate(zip(train_dataloader_sr, train_dataloader_tr)):
            
            xs,ys=train_source_data
            xt,yt=train_target_data
            
            xs_train=xs[:,5:30]
            xt_train=xt[:,5:30]
            alpha=5
            
            train_x=torch.cat((xs_train,xt_train),0)
            train_y=torch.unsqueeze(torch.cat((ys,yt),0), dim=1)
            true_t=torch.unsqueeze(torch.cat((xs[:,0],xt[:,0]),0), dim=1)
            concat_true=torch.cat((train_y,true_t),1)
            concat_pred,d_out,phi=model(train_x,alpha)
            
            
            #s_zeros_t=torch.zeros(xs_train.shape[0],1)
            #t_ones_t=torch.ones(xt_train.shape[0],1)

            #labels=torch.cat((s_zeros_t,t_ones_t),0)
           
            
            labels_discr=torch.cat((xs[:,0].type(torch.LongTensor),xt[:,0].type(torch.LongTensor)),0)
            #outputs_discr = domain_descr(phi,alpha)
            
            model.zero_grad()
            #opt_dis.zero_grad()
            

            #source_mse=criterion_reg(y0,ys)
            #target_mse=criterion_reg(y1,yt)
            domain_loss=criterion(d_out, labels_discr)
            reg_loss=regression_loss(concat_true,concat_pred)
            reg_los=reg_los+reg_loss.item()
            #combined loss
            combined_loss=domain_loss+reg_loss
            #print('Training loss: ',combined_loss.item())
            # backward propagation
            combined_loss.backward()
            dis_loss= dis_loss+domain_loss.item()
            total_loss=total_loss+combined_loss.item()
            # optimize
            optimizer.step()
            #opt_dis.step()
        #train_loss.append(loss_cal(X_train,y_train,model,alpha))
        #val_loss.append(loss_cal(X_val,y_val,model,alpha))
        d_loss.append(dis_loss)
        
        #with torch.no_grad():
        tr_r2s,was_loss_tr,d_loss_tr,tr_los,tr_ac,tr_f1=loss_cal(X_train,y_train,model,alpha) # 
        val_r2s,was_loss_val,d_loss_val,vl_los,vl_ac,vl_f1=loss_cal(X_val,y_val,model,alpha) #
        train_tloss.append(d_loss_tr)
        train_loss.append(tr_los)
        #train_loss.append(reg_los)
        train_accu.append(tr_ac)
        train_f1.append(tr_f1)
        train_wass.append(was_loss_tr)


        val_loss.append(vl_los)
        val_accu.append(vl_ac)
        val_f1.append(vl_f1)
        val_tloss.append(d_loss_val)
        val_wass.append(was_loss_val)
        tr_r2.append(tr_r2s)
        val_r2.append(val_r2s)
        
        
    #return cal_pehe(X_val,y_val,model),model
    #return total_loss,model
    #return d_loss_val+vl_los,model
    return vl_los,model
    #return cal_pehe_nn(X_val,y_val,model,alpha),model

# %%
def clear_all():
    train_loss.clear()
    train_accu.clear()
    train_f1.clear()
    val_loss.clear()
    val_accu.clear()
    val_f1.clear()
    d_loss.clear()
    train_tloss.clear()
    val_tloss.clear()
    train_wass.clear()
    val_wass.clear()
    tr_r2.clear()
    val_r2.clear()

# %%
pehe_total=[]
trails=50
model_found=False
#i=1
for i in range(1,2):
    func = lambda trial: objective(trial, i)
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(func, n_trials=trails)
    best_trial = study.best_trial
    best_model=TarNet(study.best_trial.params)
    clear_all()
    model_found=True
    best_val,model=train_evaluate(study.best_trial.params, best_model, study.best_trial,i)
    data,y=get_data('test',i)
    pehe=cal_pehe(data,y,model)

    pehe_total.append(pehe)
    del best_model
    del model
    del study
    del data
    del y
    gc.collect()
# Out:
# [I 2023-03-31 14:42:38,865] A new study created in memory with name: no-name-895a3851-f85c-41a1-9b73-c811fb54cb5c
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:42:43,352] Trial 0 finished with value: 599.115234375 and parameters: {'learning_rate': 5.6115164153345e-05, 'optimizer': 'Adam', 'batch_size': 157, 'RL11': 93, 'RL21': 93, 'RL32': 44, 'RG012': 446, 'RG022': 314, 'RG112': 367, 'RG122': 26, 'CL12': 498, 'CL22': 429}. Best is trial 0 with value: 599.115234375.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:42:47,822] Trial 1 finished with value: 315.74554443359375 and parameters: {'learning_rate': 2.6587543983272695e-05, 'optimizer': 'SGD', 'batch_size': 83, 'RL11': 276, 'RL21': 230, 'RL32': 160, 'RG012': 320, 'RG022': 85, 'RG112': 161, 'RG122': 198, 'CL12': 242, 'CL22': 406}. Best is trial 1 with value: 315.74554443359375.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:42:53,485] Trial 2 finished with value: 303.77056884765625 and parameters: {'learning_rate': 2.5081156860452307e-05, 'optimizer': 'SGD', 'batch_size': 19, 'RL11': 317, 'RL21': 100, 'RL32': 48, 'RG012': 487, 'RG022': 495, 'RG112': 417, 'RG122': 167, 'CL12': 64, 'CL22': 356}. Best is trial 2 with value: 303.77056884765625.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:42:59,995] Trial 3 finished with value: 302.1188659667969 and parameters: {'learning_rate': 7.591104805282687e-05, 'optimizer': 'SGD', 'batch_size': 16, 'RL11': 467, 'RL21': 144, 'RL32': 345, 'RG012': 170, 'RG022': 274, 'RG112': 287, 'RG122': 107, 'CL12': 497, 'CL22': 401}. Best is trial 3 with value: 302.1188659667969.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:04,048] Trial 4 finished with value: 304.1090087890625 and parameters: {'learning_rate': 0.0007568292060167617, 'optimizer': 'Adam', 'batch_size': 237, 'RL11': 59, 'RL21': 113, 'RL32': 38, 'RG012': 177, 'RG022': 209, 'RG112': 150, 'RG122': 427, 'CL12': 193, 'CL22': 155}. Best is trial 3 with value: 302.1188659667969.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:09,784] Trial 5 finished with value: 280.62091064453125 and parameters: {'learning_rate': 0.00012172847081122418, 'optimizer': 'SGD', 'batch_size': 26, 'RL11': 506, 'RL21': 399, 'RL32': 114, 'RG012': 18, 'RG022': 421, 'RG112': 367, 'RG122': 378, 'CL12': 399, 'CL22': 52}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:14,342] Trial 6 finished with value: 292.7262268066406 and parameters: {'learning_rate': 5.211124595788268e-05, 'optimizer': 'SGD', 'batch_size': 163, 'RL11': 180, 'RL21': 47, 'RL32': 170, 'RG012': 177, 'RG022': 378, 'RG112': 332, 'RG122': 456, 'CL12': 250, 'CL22': 75}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:18,586] Trial 7 finished with value: 281.17218017578125 and parameters: {'learning_rate': 0.0002669866674274458, 'optimizer': 'Adam', 'batch_size': 199, 'RL11': 261, 'RL21': 275, 'RL32': 228, 'RG012': 28, 'RG022': 69, 'RG112': 31, 'RG122': 332, 'CL12': 172, 'CL22': 268}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:43:23,148] Trial 8 failed with parameters: {'learning_rate': 0.0006533305220227731, 'optimizer': 'SGD', 'batch_size': 196, 'RL11': 129, 'RL21': 54, 'RL32': 160, 'RG012': 96, 'RG022': 478, 'RG112': 417, 'RG122': 330, 'CL12': 449, 'CL22': 415} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:43:23,149] Trial 8 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:28,589] Trial 9 finished with value: 656.300048828125 and parameters: {'learning_rate': 2.3612399244412595e-05, 'optimizer': 'Adam', 'batch_size': 209, 'RL11': 461, 'RL21': 174, 'RL32': 70, 'RG012': 129, 'RG022': 228, 'RG112': 422, 'RG122': 443, 'CL12': 19, 'CL22': 269}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:36,627] Trial 10 finished with value: 301.9524841308594 and parameters: {'learning_rate': 6.83631406502272e-05, 'optimizer': 'Adam', 'batch_size': 92, 'RL11': 484, 'RL21': 176, 'RL32': 273, 'RG012': 365, 'RG022': 196, 'RG112': 498, 'RG122': 494, 'CL12': 141, 'CL22': 263}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:44,000] Trial 11 finished with value: 445.5151672363281 and parameters: {'learning_rate': 0.000197439714830942, 'optimizer': 'SGD', 'batch_size': 70, 'RL11': 365, 'RL21': 441, 'RL32': 467, 'RG012': 23, 'RG022': 500, 'RG112': 182, 'RG122': 327, 'CL12': 373, 'CL22': 20}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:48,591] Trial 12 finished with value: 325.45330810546875 and parameters: {'learning_rate': 0.00020314357978339705, 'optimizer': 'Adam', 'batch_size': 194, 'RL11': 182, 'RL21': 358, 'RL32': 216, 'RG012': 18, 'RG022': 19, 'RG112': 64, 'RG122': 358, 'CL12': 369, 'CL22': 192}. Best is trial 5 with value: 280.62091064453125.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:43:54,171] Trial 13 finished with value: 271.4680480957031 and parameters: {'learning_rate': 0.00018000554787310762, 'optimizer': 'Adam', 'batch_size': 120, 'RL11': 369, 'RL21': 339, 'RL32': 344, 'RG012': 81, 'RG022': 389, 'RG112': 28, 'RG122': 292, 'CL12': 358, 'CL22': 506}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:00,307] Trial 14 finished with value: 380.5272216796875 and parameters: {'learning_rate': 1.0623818229569264e-05, 'optimizer': 'SGD', 'batch_size': 118, 'RL11': 382, 'RL21': 511, 'RL32': 384, 'RG012': 103, 'RG022': 404, 'RG112': 240, 'RG122': 227, 'CL12': 389, 'CL22': 497}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:06,875] Trial 15 finished with value: 313.8370666503906 and parameters: {'learning_rate': 0.00014624013266159415, 'optimizer': 'Adam', 'batch_size': 49, 'RL11': 410, 'RL21': 349, 'RL32': 324, 'RG012': 261, 'RG022': 411, 'RG112': 106, 'RG122': 278, 'CL12': 322, 'CL22': 121}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:44:12,935] Trial 16 failed with parameters: {'learning_rate': 0.0004092303510665116, 'optimizer': 'SGD', 'batch_size': 135, 'RL11': 504, 'RL21': 366, 'RL32': 471, 'RG012': 80, 'RG022': 342, 'RG112': 254, 'RG122': 383, 'CL12': 431, 'CL22': 502} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:44:12,936] Trial 16 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:44:18,610] Trial 17 failed with parameters: {'learning_rate': 0.00039004598652721706, 'optimizer': 'SGD', 'batch_size': 123, 'RL11': 415, 'RL21': 377, 'RL32': 460, 'RG012': 93, 'RG022': 348, 'RG112': 242, 'RG122': 378, 'CL12': 430, 'CL22': 321} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:44:18,611] Trial 17 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:44:24,310] Trial 18 failed with parameters: {'learning_rate': 0.0003457061645931129, 'optimizer': 'SGD', 'batch_size': 119, 'RL11': 506, 'RL21': 372, 'RL32': 447, 'RG012': 84, 'RG022': 329, 'RG112': 249, 'RG122': 379, 'CL12': 433, 'CL22': 328} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:44:24,311] Trial 18 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:44:30,120] Trial 19 failed with parameters: {'learning_rate': 0.00038807039971259854, 'optimizer': 'SGD', 'batch_size': 119, 'RL11': 504, 'RL21': 356, 'RL32': 451, 'RG012': 91, 'RG022': 357, 'RG112': 237, 'RG122': 387, 'CL12': 437, 'CL22': 327} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:44:30,121] Trial 19 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:36,211] Trial 20 finished with value: 375.374267578125 and parameters: {'learning_rate': 0.0002948194004332278, 'optimizer': 'SGD', 'batch_size': 116, 'RL11': 508, 'RL21': 356, 'RL32': 438, 'RG012': 99, 'RG022': 342, 'RG112': 240, 'RG122': 382, 'CL12': 418, 'CL22': 489}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:42,091] Trial 21 finished with value: 298.6632995605469 and parameters: {'learning_rate': 0.00011777608361742432, 'optimizer': 'SGD', 'batch_size': 48, 'RL11': 422, 'RL21': 420, 'RL32': 121, 'RG012': 245, 'RG022': 447, 'RG112': 496, 'RG122': 257, 'CL12': 297, 'CL22': 335}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:48,913] Trial 22 finished with value: 333.978271484375 and parameters: {'learning_rate': 0.00042498081679062677, 'optimizer': 'Adam', 'batch_size': 141, 'RL11': 338, 'RL21': 294, 'RL32': 292, 'RG012': 72, 'RG022': 444, 'RG112': 322, 'RG122': 302, 'CL12': 423, 'CL22': 208}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:44:55,275] Trial 23 finished with value: 296.1549987792969 and parameters: {'learning_rate': 0.00011782016106375204, 'optimizer': 'SGD', 'batch_size': 47, 'RL11': 232, 'RL21': 427, 'RL32': 508, 'RG012': 78, 'RG022': 330, 'RG112': 391, 'RG122': 380, 'CL12': 463, 'CL22': 27}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:01,449] Trial 24 finished with value: 362.6698913574219 and parameters: {'learning_rate': 0.00046305779506046295, 'optimizer': 'Adam', 'batch_size': 103, 'RL11': 431, 'RL21': 505, 'RL32': 394, 'RG012': 147, 'RG022': 268, 'RG112': 201, 'RG122': 144, 'CL12': 327, 'CL22': 104}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:06,874] Trial 25 finished with value: 377.73822021484375 and parameters: {'learning_rate': 0.0009141497013142821, 'optimizer': 'Adam', 'batch_size': 140, 'RL11': 509, 'RL21': 325, 'RL32': 109, 'RG012': 238, 'RG022': 153, 'RG112': 16, 'RG122': 405, 'CL12': 440, 'CL22': 335}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:11,814] Trial 26 finished with value: 284.70257568359375 and parameters: {'learning_rate': 0.00026291503569363496, 'optimizer': 'Adam', 'batch_size': 252, 'RL11': 280, 'RL21': 243, 'RL32': 239, 'RG012': 50, 'RG022': 100, 'RG112': 25, 'RG122': 353, 'CL12': 158, 'CL22': 263}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:16,668] Trial 27 finished with value: 307.7043151855469 and parameters: {'learning_rate': 0.00016963309754874635, 'optimizer': 'Adam', 'batch_size': 188, 'RL11': 210, 'RL21': 282, 'RL32': 199, 'RG012': 25, 'RG022': 366, 'RG112': 93, 'RG122': 316, 'CL12': 213, 'CL22': 213}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:22,208] Trial 28 finished with value: 312.2244567871094 and parameters: {'learning_rate': 9.737716362259429e-05, 'optimizer': 'Adam', 'batch_size': 214, 'RL11': 313, 'RL21': 391, 'RL32': 300, 'RG012': 65, 'RG022': 299, 'RG112': 67, 'RG122': 241, 'CL12': 114, 'CL22': 443}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:26,896] Trial 29 finished with value: 297.15838623046875 and parameters: {'learning_rate': 0.00029904813183739045, 'optimizer': 'Adam', 'batch_size': 156, 'RL11': 131, 'RL21': 221, 'RL32': 245, 'RG012': 125, 'RG022': 20, 'RG112': 121, 'RG122': 292, 'CL12': 285, 'CL22': 282}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:45:32,144] Trial 30 finished with value: 306.1014709472656 and parameters: {'learning_rate': 0.00015492022977660086, 'optimizer': 'Adam', 'batch_size': 184, 'RL11': 246, 'RL21': 299, 'RL32': 122, 'RG012': 199, 'RG022': 154, 'RG112': 286, 'RG122': 335, 'CL12': 325, 'CL22': 372}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:45:37,939] Trial 31 failed with parameters: {'learning_rate': 0.0004543959654031108, 'optimizer': 'SGD', 'batch_size': 227, 'RL11': 377, 'RL21': 473, 'RL32': 373, 'RG012': 55, 'RG022': 446, 'RG112': 64, 'RG122': 501, 'CL12': 196, 'CL22': 63} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:45:37,940] Trial 31 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:45:44,649] Trial 32 failed with parameters: {'learning_rate': 0.0004386253744157505, 'optimizer': 'SGD', 'batch_size': 230, 'RL11': 374, 'RL21': 466, 'RL32': 364, 'RG012': 49, 'RG022': 456, 'RG112': 452, 'RG122': 470, 'CL12': 358, 'CL22': 313} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:45:44,650] Trial 32 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:45:50,841] Trial 33 failed with parameters: {'learning_rate': 0.00046696788900044687, 'optimizer': 'SGD', 'batch_size': 223, 'RL11': 374, 'RL21': 463, 'RL32': 363, 'RG012': 60, 'RG022': 452, 'RG112': 57, 'RG122': 500, 'CL12': 352, 'CL22': 161} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:45:50,842] Trial 33 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:45:56,568] Trial 34 failed with parameters: {'learning_rate': 0.00023590778591673877, 'optimizer': 'SGD', 'batch_size': 230, 'RL11': 365, 'RL21': 400, 'RL32': 165, 'RG012': 312, 'RG022': 471, 'RG112': 53, 'RG122': 500, 'CL12': 197, 'CL22': 303} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:45:56,568] Trial 34 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:04,802] Trial 35 failed with parameters: {'learning_rate': 0.000480445196833786, 'optimizer': 'SGD', 'batch_size': 66, 'RL11': 357, 'RL21': 456, 'RL32': 386, 'RG012': 319, 'RG022': 454, 'RG112': 449, 'RG122': 405, 'CL12': 350, 'CL22': 62} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:04,803] Trial 35 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:10,456] Trial 36 failed with parameters: {'learning_rate': 0.0004457753275925343, 'optimizer': 'SGD', 'batch_size': 234, 'RL11': 377, 'RL21': 454, 'RL32': 351, 'RG012': 58, 'RG022': 452, 'RG112': 54, 'RG122': 481, 'CL12': 368, 'CL22': 70} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:10,457] Trial 36 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:17,149] Trial 37 failed with parameters: {'learning_rate': 0.0004216514469338661, 'optimizer': 'SGD', 'batch_size': 65, 'RL11': 377, 'RL21': 466, 'RL32': 177, 'RG012': 314, 'RG022': 454, 'RG112': 67, 'RG122': 506, 'CL12': 358, 'CL22': 62} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:17,150] Trial 37 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:23,338] Trial 38 failed with parameters: {'learning_rate': 0.00047531364686533934, 'optimizer': 'SGD', 'batch_size': 227, 'RL11': 366, 'RL21': 464, 'RL32': 168, 'RG012': 56, 'RG022': 441, 'RG112': 459, 'RG122': 509, 'CL12': 354, 'CL22': 159} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:23,339] Trial 38 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:46:30,261] Trial 39 finished with value: 325.62738037109375 and parameters: {'learning_rate': 0.00021841677176177136, 'optimizer': 'SGD', 'batch_size': 68, 'RL11': 374, 'RL21': 387, 'RL32': 375, 'RG012': 317, 'RG022': 449, 'RG112': 62, 'RG122': 512, 'CL12': 354, 'CL22': 68}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:46:36,241] Trial 40 finished with value: 323.46990966796875 and parameters: {'learning_rate': 0.0003868773184243843, 'optimizer': 'Adam', 'batch_size': 170, 'RL11': 342, 'RL21': 471, 'RL32': 179, 'RG012': 47, 'RG022': 406, 'RG112': 461, 'RG122': 390, 'CL12': 206, 'CL22': 166}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:40,591] Trial 41 failed with parameters: {'learning_rate': 0.000521830769264993, 'optimizer': 'SGD', 'batch_size': 217, 'RL11': 291, 'RL21': 329, 'RL32': 92, 'RG012': 98, 'RG022': 482, 'RG112': 133, 'RG122': 212, 'CL12': 106, 'CL22': 314} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:40,591] Trial 41 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:45,136] Trial 42 failed with parameters: {'learning_rate': 0.0005912985330910742, 'optimizer': 'SGD', 'batch_size': 231, 'RL11': 305, 'RL21': 321, 'RL32': 143, 'RG012': 100, 'RG022': 83, 'RG112': 340, 'RG122': 205, 'CL12': 94, 'CL22': 309} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:45,136] Trial 42 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:49,769] Trial 43 failed with parameters: {'learning_rate': 0.0005427764084116306, 'optimizer': 'SGD', 'batch_size': 225, 'RL11': 292, 'RL21': 325, 'RL32': 86, 'RG012': 92, 'RG022': 472, 'RG112': 350, 'RG122': 224, 'CL12': 81, 'CL22': 314} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:49,770] Trial 43 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [W 2023-03-31 14:46:54,011] Trial 44 failed with parameters: {'learning_rate': 0.0006075763702839659, 'optimizer': 'SGD', 'batch_size': 223, 'RL11': 154, 'RL21': 330, 'RL32': 94, 'RG012': 100, 'RG022': 477, 'RG112': 41, 'RG122': 469, 'CL12': 110, 'CL22': 294} because of the following error: The value nan is not acceptable..
# [W 2023-03-31 14:46:54,012] Trial 44 failed with value nan.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:46:59,059] Trial 45 finished with value: 340.57830810546875 and parameters: {'learning_rate': 0.00010415839587296515, 'optimizer': 'SGD', 'batch_size': 227, 'RL11': 299, 'RL21': 321, 'RL32': 346, 'RG012': 110, 'RG022': 468, 'RG112': 134, 'RG122': 209, 'CL12': 102, 'CL22': 312}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:47:06,368] Trial 46 finished with value: 413.4125671386719 and parameters: {'learning_rate': 0.0005262865643230363, 'optimizer': 'Adam', 'batch_size': 39, 'RL11': 404, 'RL21': 259, 'RL32': 81, 'RG012': 412, 'RG022': 299, 'RG112': 345, 'RG122': 469, 'CL12': 472, 'CL22': 455}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:47:10,384] Trial 47 finished with value: 300.8685302734375 and parameters: {'learning_rate': 0.0002376853231778765, 'optimizer': 'Adam', 'batch_size': 119, 'RL11': 125, 'RL21': 203, 'RL32': 150, 'RG012': 80, 'RG022': 63, 'RG112': 211, 'RG122': 63, 'CL12': 278, 'CL22': 139}. Best is trial 13 with value: 271.4680480957031.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:47:15,084] Trial 48 finished with value: 267.13037109375 and parameters: {'learning_rate': 0.0002783453836350095, 'optimizer': 'Adam', 'batch_size': 243, 'RL11': 205, 'RL21': 256, 'RL32': 249, 'RG012': 51, 'RG022': 91, 'RG112': 21, 'RG122': 345, 'CL12': 166, 'CL22': 238}. Best is trial 48 with value: 267.13037109375.
# /tmp/ipykernel_492835/3334483241.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# [I 2023-03-31 14:47:19,842] Trial 49 finished with value: 266.1622009277344 and parameters: {'learning_rate': 0.00030746310723186733, 'optimizer': 'Adam', 'batch_size': 251, 'RL11': 198, 'RL21': 395, 'RL32': 221, 'RG012': 43, 'RG022': 105, 'RG112': 56, 'RG122': 273, 'CL12': 235, 'CL22': 231}. Best is trial 49 with value: 266.1622009277344.

# %%
pehe_total
# Out:
# [0.5919060111045837]

# %%
print(np.mean(pehe_total))
# Out:
# 0.5919060111045837

# %%
val_r2
# Out:
# [-3.840926170349121,
#  -3.751707077026367,
#  -3.6591005325317383,
#  -3.5568690299987793,
#  -3.4487881660461426,
#  -3.3228836059570312,
#  -3.19222354888916,
#  -3.044527530670166,
#  -2.8792686462402344,
#  -2.7079062461853027,
#  -2.5088024139404297,
#  -2.297600030899048,
#  -2.083927631378174,
#  -1.8493800163269043,
#  -1.6064326763153076,
#  -1.3547332286834717,
#  -1.1045794486999512,
#  -0.855377197265625,
#  -0.6179637908935547,
#  -0.3933413028717041,
#  -0.1810668706893921,
#  0.005842983722686768,
#  0.1510353684425354,
#  0.2514961361885071,
#  0.3167686462402344,
#  0.3257710933685303,
#  0.30262964963912964,
#  0.25435471534729004,
#  0.20372140407562256,
#  0.1736965775489807,
#  0.16171300411224365,
#  0.18597543239593506,
#  0.2140771746635437,
#  0.2654842734336853,
#  0.3074198365211487,
#  0.3336414098739624,
#  0.3601350784301758,
#  0.37544524669647217,
#  0.37343382835388184,
#  0.37661147117614746,
#  0.3687248229980469,
#  0.36369621753692627,
#  0.3407623767852783,
#  0.34332358837127686,
#  0.33891957998275757,
#  0.3285648822784424,
#  0.32671868801116943,
#  0.3419542908668518,
#  0.3533242344856262,
#  0.37294846773147583,
#  0.3791162967681885,
#  0.391735315322876,
#  0.4128224849700928,
#  0.4190410375595093,
#  0.44444453716278076,
#  0.44697386026382446,
#  0.4500444531440735,
#  0.47178107500076294,
#  0.47091144323349,
#  0.4729892611503601,
#  0.48921751976013184,
#  0.4795447587966919,
#  0.48226433992385864,
#  0.48547428846359253,
#  0.4847985506057739,
#  0.5030016899108887,
#  0.4953867793083191,
#  0.5127604007720947,
#  0.5121792554855347,
#  0.5107907056808472,
#  0.5212303400039673,
#  0.5144192576408386,
#  0.5170251131057739,
#  0.5186260938644409,
#  0.5175879001617432,
#  0.5251337289810181,
#  0.5311792492866516,
#  0.5412923097610474,
#  0.5483856201171875,
#  0.5443999171257019,
#  0.5521895289421082,
#  0.5593042373657227,
#  0.5657050609588623,
#  0.5613465309143066,
#  0.5658172965049744,
#  0.580620527267456,
#  0.5784722566604614,
#  0.5900894403457642,
#  0.5919827222824097,
#  0.5915882587432861,
#  0.5999534130096436,
#  0.5932866334915161,
#  0.593777060508728,
#  0.5937346816062927,
#  0.6050797700881958,
#  0.5931762456893921,
#  0.6075081825256348,
#  0.6114791631698608,
#  0.6105835437774658,
#  0.6145964860916138,
#  0.6156895160675049,
#  0.6202574968338013,
#  0.6181312799453735,
#  0.628569483757019,
#  0.6237965822219849,
#  0.6316450834274292,
#  0.6319509744644165,
#  0.6344392895698547,
#  0.6428688764572144,
#  0.6407469511032104,
#  0.6465399265289307,
#  0.6220691204071045,
#  0.6452440619468689,
#  0.6489366292953491,
#  0.6556079983711243,
#  0.6593581438064575,
#  0.6586601734161377,
#  0.6490047574043274,
#  0.6641279458999634,
#  0.6619881987571716,
#  0.6714917421340942,
#  0.6724757552146912,
#  0.67638099193573,
#  0.6755365133285522,
#  0.6803682446479797,
#  0.6691242456436157,
#  0.6903846859931946,
#  0.6883119940757751,
#  0.6828896403312683,
#  0.6954672336578369,
#  0.6958439350128174,
#  0.6936767101287842,
#  0.6866040229797363,
#  0.6940598487854004,
#  0.7058780193328857,
#  0.7095026969909668,
#  0.6982922554016113,
#  0.7064335346221924,
#  0.7040661573410034,
#  0.6919944882392883,
#  0.7119097709655762,
#  0.7146055698394775,
#  0.711876392364502,
#  0.7213447093963623,
#  0.707722544670105,
#  0.7138535976409912,
#  0.7222621440887451,
#  0.7245043516159058,
#  0.7160024046897888,
#  0.7288618087768555,
#  0.7289436459541321,
#  0.7348239421844482,
#  0.7275320887565613,
#  0.7347861528396606,
#  0.719839334487915,
#  0.7324130535125732,
#  0.732709527015686,
#  0.7349193096160889,
#  0.731314480304718,
#  0.7346729040145874,
#  0.7440926432609558,
#  0.7350025177001953,
#  0.7353072166442871,
#  0.7331361770629883,
#  0.7430272698402405,
#  0.7423096895217896,
#  0.7426205277442932,
#  0.7464504241943359,
#  0.7391778230667114,
#  0.7383927702903748,
#  0.7423387765884399,
#  0.7333545684814453,
#  0.7508012056350708,
#  0.750764787197113,
#  0.7551165819168091,
#  0.745370626449585,
#  0.7600130438804626,
#  0.7477247714996338,
#  0.7453131675720215,
#  0.7498985528945923,
#  0.751240611076355,
#  0.7532760500907898,
#  0.7413945198059082,
#  0.7547979354858398,
#  0.7534517049789429,
#  0.7546209692955017,
#  0.7603808641433716,
#  0.756921648979187,
#  0.7515804767608643,
#  0.7425142526626587,
#  0.7605661153793335,
#  0.7636995315551758,
#  0.7533004879951477,
#  0.7612923383712769,
#  0.7463455200195312,
#  0.7588982582092285,
#  0.7535876035690308,
#  0.7514209747314453,
#  0.7601655125617981,
#  0.761038064956665,
#  0.7599137425422668,
#  0.758527398109436,
#  0.77110755443573,
#  0.7650716304779053,
#  0.7624478936195374,
#  0.7689164876937866,
#  0.7585481405258179,
#  0.7586885690689087,
#  0.769347071647644,
#  0.7658997774124146,
#  0.7532700300216675,
#  0.7691837549209595,
#  0.7725796103477478,
#  0.7609493136405945,
#  0.7651738524436951,
#  0.764357328414917,
#  0.7643670439720154,
#  0.7682229280471802,
#  0.7713587880134583,
#  0.7665127515792847,
#  0.7732833623886108,
#  0.7688660621643066,
#  0.7771203517913818,
#  0.7719957232475281,
#  0.755887508392334,
#  0.7587909698486328,
#  0.7691577076911926,
#  0.7677426338195801,
#  0.7688322067260742,
#  0.7649962902069092,
#  0.7691891193389893,
#  0.7689489126205444,
#  0.7588909268379211,
#  0.7671257853507996,
#  0.7606828212738037,
#  0.7616694569587708,
#  0.7589805722236633,
#  0.7644044160842896,
#  0.7658838033676147,
#  0.7739713191986084,
#  0.7727657556533813,
#  0.7704227566719055,
#  0.7664705514907837,
#  0.7763935327529907,
#  0.7648622989654541,
#  0.7622455358505249,
#  0.765067994594574,
#  0.7714751958847046,
#  0.7683345079421997,
#  0.763355016708374,
#  0.76455157995224,
#  0.7672271728515625,
#  0.7812615633010864,
#  0.7764489054679871,
#  0.7614356875419617,
#  0.7679774761199951,
#  0.7649945020675659,
#  0.768410861492157,
#  0.777014970779419,
#  0.7712151408195496,
#  0.7659773826599121,
#  0.777076005935669,
#  0.7707934379577637,
#  0.7704123258590698,
#  0.7714734673500061,
#  0.7644289135932922,
#  0.7686572074890137,
#  0.7699690461158752,
#  0.7749096751213074,
#  0.771405816078186,
#  0.7732672691345215,
#  0.7714846730232239,
#  0.7745473384857178,
#  0.7640151381492615,
#  0.7733641862869263,
#  0.7720105051994324,
#  0.7699005603790283,
#  0.7807920575141907,
#  0.7632003426551819,
#  0.7807472944259644,
#  0.7757472991943359,
#  0.7676694393157959,
#  0.7768495082855225,
#  0.7684650421142578,
#  0.7608733177185059,
#  0.7781540751457214,
#  0.767469584941864,
#  0.7633218765258789,
#  0.7738515734672546,
#  0.7680628299713135,
#  0.7737208604812622,
#  0.7687985897064209,
#  0.7708567380905151,
#  0.7731084823608398,
#  0.7677456140518188,
#  0.7809394598007202,
#  0.77166348695755,
#  0.7754245400428772,
#  0.7694109678268433,
#  0.7761916518211365]

# %%
plt.plot(train_loss, label='Regression loss on training')
plt.plot(val_loss, label='Regression loss on validation')
plt.legend()
plt.show()

# %%
plt.plot(train_wass,label='IPM-MMD on training')
#plt.plot(val_wass,label='IPM-Wasserstein on validation')
plt.legend()
plt.show()

# %%
plt.plot(val_wass,label='IPM-MMD on validation',color='#FFA500')
plt.legend()
plt.show()

# %%
x_axis = ['train', 'validation']
y_axis = [0.84, 0.77]

plt.bar(x_axis, y_axis,color=['blue', '#FFA500'])
plt.title('R2 score on train and validation')
plt.xlabel('Data')
plt.ylabel('R2 score')
plt.show()

# %%
#np.savetxt("Ours1_100_(IHDPB-Hyper_val_300ep_outsample).csv", pehe_total,delimiter =", ", fmt ='% s')

# %%
#concate_pred,d_out,phi=model()

data_orig=data.iloc[:,5:30]
labels=data.iloc[:,0]

# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result = tsne.fit_transform(data_orig) #combined_features combined_transformed
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'label': labels})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df, ax=ax,s=120)
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

# %%
# wasserstein distance
loss1 = SamplesLoss(loss="sinkhorn", p=2, blur=.05)
t_zero=tsne_result[:,0]
t_one=tsne_result[:,1]

wasser = loss1(torch.unsqueeze(torch.from_numpy(t_zero.astype(np.float32)),dim=1),torch.unsqueeze(torch.from_numpy(t_one.astype(np.float32)),dim=1))

# %%
wasser
# Out:
# tensor(3.4914)

# %%
data_for_trans=data.iloc[:,5:30]
labels_for_trans=data.iloc[:,0]

data_tensor=torch.from_numpy(data_for_trans.to_numpy().astype(np.float32))
concate_pred,d_out,phi=model(data_tensor,0.5)

#data=data[:,5:30]
#labels=data[:,0]

# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result_tr = tsne.fit_transform(phi.detach().cpu().numpy()) #combined_features combined_transformed
tsne_result_df_tr = pd.DataFrame({'tsne_1': tsne_result_tr[:,0], 'tsne_2': tsne_result_tr[:,1], 'label': labels_for_trans})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df_tr, ax=ax,s=120)
lim = (tsne_result_tr.min()-5, tsne_result_tr.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

# %%
# wasserstein distance
loss1 = SamplesLoss(loss="sinkhorn", p=2, blur=.05)
t_zero_tr=tsne_result_tr[:,0]
t_one_tr=tsne_result_tr[:,1]
wasser_tr = loss1(torch.unsqueeze(torch.from_numpy(t_zero_tr.astype(np.float32)),dim=1),torch.unsqueeze(torch.from_numpy(t_one_tr.astype(np.float32)),dim=1))

# %%
wasser_tr
# Out:
# tensor(2.8654)

# %%
plt.plot(train_tloss,label='Cross entropy loss of treatment classifier on training')
plt.plot(val_tloss,label='Cross entropy loss of treatment classifier on validation')
plt.legend()
plt.show()

# %%
'''
full network origional with optuna

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], params['CL22']), #
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,d_out

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None




def objective(trial,i):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 512),
          'RL21': trial.suggest_int('RL21', 16, 512),
          'RL32': trial.suggest_int('RL32', 16, 512),
          'RG012':trial.suggest_int('RG012', 16, 512),
        'RG022':trial.suggest_int('RG022', 16, 512),
        'RG112':trial.suggest_int('RG112', 16, 512),
        'RG122':trial.suggest_int('RG122', 16, 512),
        'CL12':trial.suggest_int('CL12', 16, 512),
        'CL22':trial.suggest_int('CL22', 16, 512)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i)

    return pehe


'''
# Out:
# '\nfull network origional with optuna\n\nclass TarNet(nn.Module):\n    def __init__(self,params):\n        super(TarNet, self).__init__()\n        self.encoder1 = nn.Linear(25, params[\'RL11\'])\n        self.encoder2 = nn.Linear(params[\'RL11\'], params[\'RL21\'])\n        self.encoder3 = nn.Linear(params[\'RL21\'], params[\'RL32\'])\n        \n        self.dis1_d = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'CL12\']), #params[\'CL12\']\n            nn.ReLU(),\n            nn.Dropout(p=0.1)\n        )\n        self.dis2_d = nn.Sequential(\n            nn.Linear(params[\'CL12\'], params[\'CL22\']), #\n            nn.ReLU(),\n            nn.Dropout(p=.01)\n        )\n        \n        self.dis3_d = nn.Sequential(\n            nn.Linear(params[\'CL22\'], 2),\n            nn.ReLU(),\n            nn.Dropout(p=.01)\n        )\n       \n        \n        self.regressor1_y0 = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'RG012\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressor2_y0 = nn.Sequential(\n            nn.Linear(params[\'RG012\'], params[\'RG022\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressorO_y0 = nn.Linear(params[\'RG022\'], 1)\n\n        self.regressor1_y1 = nn.Sequential(\n            nn.Linear(params[\'RL32\'], params[\'RG112\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressor2_y1 = nn.Sequential(\n            nn.Linear(params[\'RG112\'], params[\'RG122\']),\n            nn.ELU(),\n            nn.Dropout(p=.01),\n        )\n        self.regressorO_y1 = nn.Linear(params[\'RG122\'], 1)\n\n\n\n    def forward(self, inputs,alpha=0.5):\n        x = nn.functional.elu(self.encoder1(inputs))\n        phi= nn.functional.elu(self.encoder2(x))\n        phi = nn.functional.elu(self.encoder3(phi))\n        \n        out_y0 = self.regressor1_y0(phi)\n        out_y0 = self.regressor2_y0(out_y0)\n        y0 = self.regressorO_y0(out_y0)\n\n        out_y1 = self.regressor1_y1(phi)\n        out_y1 = self.regressor2_y1(out_y1)\n        y1 = self.regressorO_y1(out_y1)\n\n        concat = torch.cat((y0, y1), 1)\n        \n        rev = ReverseLayerF.apply(phi, alpha)\n        \n        out_d1 = self.dis1_d(rev)\n        out_d2 = self.dis2_d(out_d1)\n        d_out = self.dis3_d(out_d2)\n\n        concat = torch.cat((y0, y1), 1)\n        return concat,d_out\n\nclass ReverseLayerF(Function):\n    @staticmethod\n    def forward(ctx, x, alpha):\n        ctx.alpha = alpha\n\n        return x.view_as(x)\n\n    @staticmethod\n    def backward(ctx, grad_output):\n        output = grad_output.neg() * ctx.alpha\n\n        return output, None\n    \nclass GRL(Function):\n    @staticmethod\n    def forward(ctx, tensor, constant):\n        ctx.constant = constant\n        return tensor * constant\n    @staticmethod\n    def backward(ctx, grad_output):\n        return grad_output.neg() * ctx.constant, None\n\n\n\n\ndef objective(trial,i):\n\n    params = {\n          \'learning_rate\': trial.suggest_loguniform(\'learning_rate\', 1e-5, 1e-3),\n          \'optimizer\': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),\n          \'batch_size\':trial.suggest_int(\'batch_size\', 8, 256),\n          \'RL11\':trial.suggest_int(\'RL11\', 16, 512),\n          \'RL21\': trial.suggest_int(\'RL21\', 16, 512),\n          \'RL32\': trial.suggest_int(\'RL32\', 16, 512),\n          \'RG012\':trial.suggest_int(\'RG012\', 16, 512),\n        \'RG022\':trial.suggest_int(\'RG022\', 16, 512),\n        \'RG112\':trial.suggest_int(\'RG112\', 16, 512),\n        \'RG122\':trial.suggest_int(\'RG122\', 16, 512),\n        \'CL12\':trial.suggest_int(\'CL12\', 16, 512),\n        \'CL22\':trial.suggest_int(\'CL22\', 16, 512)\n          \n          }\n\n    model = TarNet(params)\n\n    pehe,model= train_evaluate(params, model, trial,i)\n\n    return pehe\n\n\n'

# %%
'''
Library way: all networks have two layers 
1.38

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL21'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL21'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], 1),#params['RG022']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL21'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], 1), #params['RG122']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        #phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        #y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        #y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((out_y0, out_y1), 1)
        return concat,out_d2

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

'''

# %%
'''
Tutorial way: layers and neurons all changed

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], params['CL22']), #
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], 1), #params['RG022']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], 1), #params['RG122']
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        #phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        #y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        #y1 = self.regressorO_y1(out_y1)

        concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        d_out = self.dis3_d(out_d2)

        concat = torch.cat((out_y0, out_y1), 1)
        return concat,d_out

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None




def objective(trial,i):

    params = {
          'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
          'optimizer': trial.suggest_categorical("optimizer", ["Adam", "SGD"]),
          'batch_size':trial.suggest_int('batch_size', 8, 256),
          'RL11':trial.suggest_int('RL11', 16, 32),
          'RL21': trial.suggest_int('RL21', 16, 32),
          'RL32': trial.suggest_int('RL32', 16, 32),
          'RG012':trial.suggest_int('RG012', 16, 32),
        'RG022':trial.suggest_int('RG022', 16, 32),
        'RG112':trial.suggest_int('RG112', 16, 32),
        'RG122':trial.suggest_int('RG122', 16, 32),
        'CL12':trial.suggest_int('CL12', 16, 32),
        'CL22':trial.suggest_int('CL22', 16, 32)
          
          }

    model = TarNet(params)

    pehe,model= train_evaluate(params, model, trial,i)

    return pehe


'''

# %%
'''
result 0.71 seed=42, result 0.79 seed=0, result 0.72 seed=1
one change: with 2 layers of classifier

class TarNet(nn.Module):
    def __init__(self,params):
        super(TarNet, self).__init__()
        self.encoder1 = nn.Linear(25, params['RL11'])
        self.encoder2 = nn.Linear(params['RL11'], params['RL21'])
        self.encoder3 = nn.Linear(params['RL21'], params['RL32'])
        
        self.dis1_d = nn.Sequential(
            nn.Linear(params['RL32'], params['CL12']), #params['CL12']
            nn.ReLU(),
            nn.Dropout(p=0.1)
        )
        self.dis2_d = nn.Sequential(
            nn.Linear(params['CL12'], 2), #params['CL22']
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
        
        self.dis3_d = nn.Sequential(
            nn.Linear(params['CL22'], 2),
            nn.ReLU(),
            nn.Dropout(p=.01)
        )
       
        
        self.regressor1_y0 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG012']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y0 = nn.Sequential(
            nn.Linear(params['RG012'], params['RG022']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y0 = nn.Linear(params['RG022'], 1)

        self.regressor1_y1 = nn.Sequential(
            nn.Linear(params['RL32'], params['RG112']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressor2_y1 = nn.Sequential(
            nn.Linear(params['RG112'], params['RG122']),
            nn.ELU(),
            nn.Dropout(p=.01),
        )
        self.regressorO_y1 = nn.Linear(params['RG122'], 1)



    def forward(self, inputs,alpha=0.5):
        x = nn.functional.elu(self.encoder1(inputs))
        phi= nn.functional.elu(self.encoder2(x))
        phi = nn.functional.elu(self.encoder3(phi))
        
        out_y0 = self.regressor1_y0(phi)
        out_y0 = self.regressor2_y0(out_y0)
        y0 = self.regressorO_y0(out_y0)

        out_y1 = self.regressor1_y1(phi)
        out_y1 = self.regressor2_y1(out_y1)
        y1 = self.regressorO_y1(out_y1)

        #concat = torch.cat((y0, y1), 1)
        
        rev = ReverseLayerF.apply(phi, alpha)
        
        out_d1 = self.dis1_d(rev)
        out_d2 = self.dis2_d(out_d1)
        #d_out = self.dis3_d(out_d2)

        concat = torch.cat((y0, y1), 1)
        return concat,out_d2

class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None
    
class GRL(Function):
    @staticmethod
    def forward(ctx, tensor, constant):
        ctx.constant = constant
        return tensor * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None


'''
